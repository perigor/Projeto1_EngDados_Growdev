# %% [markdown]
# <a href="https://colab.research.google.com/github/perigor/Projeto1_EngDados_Growdev/blob/main/Projeto_1_EngDados_InstaMarcitoCastro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto 1 - Growdev - Engenharia de Dados
#
# ## Análise de Instragram de Influencer para marca Vans
# ### Influencer: Marcito Castro
#
# **Instagram:** marcitocastro (482001976) - https://www.instagram.com/marcitocastro/
#
# **Fonte dedados:** https://rapidapi.com/mrngstar/api/instagram-scraper-api3
#
# ------------------
#
#
#
# - [x] Fotografia do perfil dia a dia (1 request por dia).
# - [x] Informações gerais sobre as ultimas 24 postagens (2 requests por dia).
# - [X] Informações da ultima postagem (comentarios, Gerais do post) (17 requests por dia).
# - [X] Classificação de comentários (Positivo, Negativo, Humor, Neutro).

# %% [markdown]
# ## Instalando Dependências / Install dependencies

# %%
# Instalando a bibliotecão que requisição

# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)

# %%
# Intalando API GeminiAI

# !pip install -U google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.8.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.9 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.6.9)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.19.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.137.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.9.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.9->google-generativeai) (1.24.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.23.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.9->google-generativeai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.9->google-generativeai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.8.30)

# %%
# !apt-get update # Atualizao repositório so apt_get
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null # Instalação do Java para rodar o Apache Spark.
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz # Download Apache Spark.
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz # Descompactando o arquivo tgz.
# !pip install -q findspark # Instala o pacote Python 'findspark'. O findspark ajuda a configurar o ambiente PySpark no sistema PATH.
# !ls
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy Release
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Fetched 261 kB in 3s (77.9 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# sample_data		   spark-3.1.1-bin-hadoop3.2.tgz    spark-3.1.1-bin-hadoop3.2.tgz.2
# spark-3.1.1-bin-hadoop3.2  spark-3.1.1-bin-hadoop3.2.tgz.1

# %%
# Instalação de vesão 3.1.1 do pyspark

# !pip install pyspark==3.1.1
# Out:
# Requirement already satisfied: pyspark==3.1.1 in /usr/local/lib/python3.10/dist-packages (3.1.1)
# Requirement already satisfied: py4j==0.10.9 in /usr/local/lib/python3.10/dist-packages (from pyspark==3.1.1) (0.10.9)

# %% [markdown]
# ## Importando bibliotecas / Important libraries

# %%
import requests # Importa a biblioteca 'requests' para fazer requisições HTTP.
import json # Importa a biblioteca 'json' para trabalhar com dados JSON.
import findspark # Importa 'findspark' para facilitar a configuração do PySpark no ambiente de execução.
import os # Importa 'os' para interagir com o sistema operacional.
from google.colab import userdata # Importa 'userdata' do Google Colab, que pode ser usado para gerenciar dados de usuário (nota: 'userdata' não é uma biblioteca padrão).

import sys # Importa 'sys' para manipulação do sistema e parâmetros da execução.


# Importa 'pandas' para manipulação e análise de dados.
import pandas as pd


# Importa o PySpark para processamento distribuído de dados.
import pyspark

# Importa tipos e funções necessários do PySpark para manipulação de DataFrames.
from pyspark.sql import DataFrame, SparkSession
from typing import List
import pyspark.sql.types as T
import pyspark.sql.functions as F

# Importa o SparkSession do PySpark para criar uma sessão Spark.
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType

from array import ArrayType

import google.generativeai as genai
import os

# %% [markdown]
# ## Definições / Set

# %%
# Obtém a URL do serviço de API a partir dos dados do usuário do Google Colab.

url = userdata.get('url')

# Define o nome de usuário do influenciador que será pesquisado.

influencer = "marcitocastro"

# Configura os cabeçalhos HTTP necessários para autenticar a requisição na API.

headers = {
	"x-rapidapi-key": userdata.get('x-rapidapi-key'),
	"x-rapidapi-host": "instagram-scraper-api3.p.rapidapi.com"
}

# Inicializa uma variável para armazenar o código da última postagem

codigo_ultima_postagem = ''

# Define as variáveis de ambiente para Java e Spark.
# Essas variáveis são necessárias para o PySpark funcionar corretamente no ambiente.

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
# Inicializa findspark para configurar o ambiente do PySpark.

findspark.init()
findspark.find()

# Cria uma sessão do PySpark.
spark = SparkSession \
       .builder \
       .appName("Our First Spark Example") \
       .getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://1f52628f2414:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Our First Spark Example</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Extraindo Informações / Get Info

# %% [markdown]
# ### Extraindo informações do Perfil / Get info Profile

# %%
# Definindo parâmetro de consulta para API.
# Definindo método da API para chamar informações.

querystring = {"username_or_id": influencer}

method = 'user_info'

response = requests.get(f'{url}{method}',
                          headers=headers,
                          params=querystring)

response_instagram = response.json()

# %%
# Verificando informações do Usuário, já convertido em JSON.

response_instagram.get("data",'Atributo não encontrado')
# Out:
# {'primary_profile_link_type': 0,
#  'show_fb_link_on_profile': False,
#  'show_fb_page_link_on_profile': False,
#  'can_hide_category': True,
#  'account_type': 3,
#  'current_catalog_id': None,
#  'mini_shop_seller_onboarding_status': None,
#  'account_category': '',
#  'can_add_fb_group_link_on_profile': False,
#  'can_use_affiliate_partnership_messaging_as_creator': False,
#  'can_use_affiliate_partnership_messaging_as_brand': False,
#  'existing_user_age_collection_enabled': True,
#  'fbid_v2': '17841400539287531',
#  'feed_post_reshare_disabled': False,
#  'full_name': 'Marcito Castro',
#  'has_guides': False,
#  'has_ig_profile': True,
#  'has_public_tab_threads': True,
#  'highlight_reshare_disabled': False,
#  'include_direct_blacklist_status': True,
#  'is_direct_roll_call_enabled': True,
#  'is_eligible_for_meta_verified_links_in_reels': True,
#  'is_new_to_instagram': False,
#  'is_parenting_account': False,
#  'is_private': False,
#  'is_secondary_account_creation': False,
#  'pk': '482001976',
#  'pk_id': '482001976',
#  'profile_type': 0,
#  'show_account_transparency_details': True,
#  'show_ig_app_switcher_badge': False,
#  'show_post_insights_entry_point': True,
#  'show_text_post_app_switcher_badge': True,
#  'third_party_downloads_enabled': 1,
#  'is_opal_enabled': False,
#  'strong_id__': '482001976',
#  'id': '482001976',
#  'biography': '🎤 Comediante estandart\n✊🏻 Compre no Sarandi ✊🏻\n📥 @artistaria',
#  'biography_with_entities': {'raw_text': '🎤 Comediante estandart\n✊🏻 Compre no Sarandi ✊🏻\n📥 @artistaria',
#   'entities': [{'user': {'id': '283038768', 'username': 'artistaria'}}]},
#  'external_lynx_url': 'https://l.instagram.com/?u=https%3A%2F%2Fonne.link%2Frespeitavila&e=AT2YwieySIT0QNP_8whcD_5xi9madlkCoE0kdtnOkxtJNERiX2-s4qKJjvqI-bME5ikYxf_0kgAfoHj1Ib-AlfWdn9svSmfokCfwz7Q',
#  'external_url': 'https://onne.link/respeitavila',
#  'has_biography_translation': True,
#  'can_hide_public_contacts': True,
#  'category': 'Comedian',
#  'should_show_category': True,
#  'category_id': '1610',
#  'is_category_tappable': True,
#  'should_show_public_contacts': False,
#  'is_eligible_for_smb_support_flow': True,
#  'is_eligible_for_lead_center': False,
#  'lead_details_app_id': 'com.bloks.www.ig.smb.services.lead_gen.all_leads',
#  'is_business': False,
#  'professional_conversion_suggested_account_type': 3,
#  'direct_messaging': '',
#  'instagram_location_id': '',
#  'address_street': '',
#  'business_contact_method': 'UNKNOWN',
#  'city_id': '0',
#  'city_name': '',
#  'contact_phone_number': '',
#  'is_profile_audio_call_enabled': False,
#  'latitude': 0,
#  'longitude': 0,
#  'public_email': '',
#  'public_phone_country_code': '',
#  'public_phone_number': '',
#  'zip': '',
#  'displayed_action_button_partner': None,
#  'smb_delivery_partner': None,
#  'smb_support_delivery_partner': None,
#  'displayed_action_button_type': '',
#  'smb_support_partner': None,
#  'is_call_to_action_enabled': False,
#  'num_of_admined_pages': None,
#  'page_id': None,
#  'page_name': None,
#  'ads_page_id': '106089742597199',
#  'ads_page_name': 'Marcito Castro',
#  'shopping_post_onboard_nux_type': None,
#  'ads_incentive_expiration_date': None,
#  'account_badges': [],
#  'additional_business_addresses': [],
#  'auto_expand_chaining': None,
#  'bio_links': [{'link_id': '18011225563703977',
#    'url': 'https://onne.link/respeitavila',
#    'lynx_url': 'https://l.instagram.com/?u=https%3A%2F%2Fonne.link%2Frespeitavila&e=AT2YwieySIT0QNP_8whcD_5xi9madlkCoE0kdtnOkxtJNERiX2-s4qKJjvqI-bME5ikYxf_0kgAfoHj1Ib-AlfWdn9svSmfokCfwz7Q',
#    'link_type': 'external',
#    'title': '🎭 INGRESSOS',
#    'image_url': '',
#    'icon_url': '',
#    'is_pinned': False,
#    'is_verified': False,
#    'open_external_url_with_in_app_browser': True}],
#  'birthday_today_visibility_for_viewer': 'NOT_VISIBLE',
#  'broadcast_chat_preference_status': {'json_response': '{"status":"ok","status_code":"200","is_broadcast_chat_creator":true,"notification_setting_type":2}'},
#  'can_use_branded_content_discovery_as_brand': False,
#  'can_use_branded_content_discovery_as_creator': False,
#  'can_use_paid_partnership_messaging_as_creator': False,
#  'chaining_upsell_cards': [],
#  'creator_shopping_info': {'linked_merchant_accounts': []},
#  'enable_add_school_in_edit_profile': False,
#  'fan_club_info': {'autosave_to_exclusive_highlight': None,
#   'connected_member_count': None,
#   'fan_club_id': None,
#   'fan_club_name': None,
#   'has_enough_subscribers_for_ssc': None,
#   'is_fan_club_gifting_eligible': None,
#   'is_fan_club_referral_eligible': None,
#   'subscriber_count': None,
#   'fan_consideration_page_revamp_eligiblity': None},
#  'follow_friction_type': 0,
#  'follower_count': 818737,
#  'following_count': 3686,
#  'has_anonymous_profile_picture': False,
#  'has_chaining': True,
#  'has_chains': False,
#  'has_collab_collections': False,
#  'has_exclusive_feed_content': False,
#  'has_fan_club_subscriptions': True,
#  'has_gen_ai_personas_for_profile_banner': False,
#  'has_highlight_reels': True,
#  'has_igtv_series': True,
#  'has_music_on_profile': False,
#  'has_private_collections': False,
#  'has_videos': True,
#  'hd_profile_pic_url_info': {'height': 1080,
#   'url': 'https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYCW4aUI9zsCYaadBcxDDGv2E9btIvVxM-bUww1dYqx_dQ&oe=66EBAE67&_nc_sid=1e20d2',
#   'width': 1080},
#  'hd_profile_pic_versions': [{'height': 320,
#    'url': 'https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s320x320&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYCYj7ew_DO7avu0M9ia37etJqif5h_8pC1h21f1O6N_hA&oe=66EBAE67&_nc_sid=1e20d2',
#    'width': 320},
#   {'height': 640,
#    'url': 'https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s640x640&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYDrxUrZLJaCZ9N3Rmk72QIhHcZtnarR4WMeewderOKk1g&oe=66EBAE67&_nc_sid=1e20d2',
#    'width': 640}],
#  'highlights_tray_type': 'DEFAULT',
#  'interop_messaging_user_fbid': 110222783707924,
#  'is_creator_agent_enabled': False,
#  'is_eligible_for_diverse_owned_business_info': False,
#  'is_eligible_for_meta_verified_enhanced_link_sheet': False,
#  'is_eligible_for_meta_verified_enhanced_link_sheet_consumption': False,
#  'is_eligible_for_meta_verified_multiple_addresses_creation': False,
#  'is_eligible_for_meta_verified_multiple_addresses_consumption': False,
#  'is_eligible_for_meta_verified_related_accounts': False,
#  'is_eligible_for_post_boost_mv_upsell': False,
#  'meta_verified_related_accounts_count': 0,
#  'is_meta_verified_related_accounts_display_enabled': False,
#  'is_eligible_for_meta_verified_label': True,
#  'is_eligible_to_display_diverse_owned_business_info': False,
#  'is_in_canada': False,
#  'is_interest_account': True,
#  'is_memorialized': False,
#  'is_potential_business': False,
#  'is_regulated_news_in_viewer_location': False,
#  'is_remix_setting_enabled_for_posts': True,
#  'is_remix_setting_enabled_for_reels': True,
#  'is_profile_broadcast_sharing_enabled': True,
#  'is_regulated_c18': False,
#  'is_stories_teaser_muted': False,
#  'is_recon_ad_cta_on_profile_eligible_with_viewer': True,
#  'is_supervision_features_enabled': False,
#  'is_verified': True,
#  'is_whatsapp_linked': False,
#  'latest_besties_reel_media': 0,
#  'latest_reel_media': 1726324117,
#  'live_subscription_status': 'default',
#  'media_count': 4053,
#  'merchant_checkout_style': 'none',
#  'nametag': {'available_theme_colors': [-1,
#    7747834,
#    13828293,
#    16712041,
#    16742912,
#    0],
#   'background_image_url': '',
#   'emoji': '😀',
#   'emoji_color': 0,
#   'gradient': 3,
#   'is_background_image_blurred': True,
#   'mode': 0,
#   'selected_theme_color': -1,
#   'selfie_sticker': 0,
#   'selfie_url': ''},
#  'open_external_url_with_in_app_browser': True,
#  'pinned_channels_info': {'has_public_channels': False,
#   'pinned_channels_list': []},
#  'profile_pic_id': '3436382941194761236_482001976',
#  'profile_pic_url': 'https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYDjX86ManWK_IVscVnrk4YdP2wj946RRqdz0B6qsRh3Kw&oe=66EBAE67&_nc_sid=1e20d2',
#  'pronouns': [],
#  'recon_features': {'enable_recon_cta': True},
#  'relevant_news_regulation_locations': [],
#  'remove_message_entrypoint': False,
#  'seller_shoppable_feed_type': 'none',
#  'show_schools_badge': None,
#  'show_shoppable_feed': False,
#  'show_text_post_app_badge': True,
#  'spam_follower_setting_enabled': True,
#  'text_app_last_visited_time': None,
#  'text_post_app_joiner_number': 5927523,
#  'text_post_app_joiner_number_label': '5,927,523',
#  'text_post_app_badge_label': 'marcitocastro',
#  'text_post_new_post_count': 0,
#  'total_ar_effects': 1,
#  'total_clips_count': 1,
#  'total_igtv_videos': 549,
#  'transparency_product_enabled': False,
#  'username': 'marcitocastro',
#  'is_profile_picture_expansion_enabled': True,
#  'recs_from_friends': {'enable_recs_from_friends': False,
#   'recs_from_friends_entry_point_type': 'banner'},
#  'adjusted_banners_order': [],
#  'is_eligible_for_request_message': False,
#  'is_open_to_collab': False,
#  'threads_profile_glyph_url': 'https://www.threads.net/@marcitocastro?modal=true&xmt=AQGzNddeZfnEwf-ECwSZaeT-GhP24TV7QSk3dtAscYFyS7k',
#  'has_ever_selected_topics': False,
#  'is_oregon_custom_gender_consented': False,
#  'about': None}

# %%
# Extração dos dados do perfil
perfil = response_instagram.get("data")

# Extraindo os campos principais
nome_perfil = perfil.get('full_name')  # Nome do perfil
id_perfil = perfil.get('id')  # ID do perfil
biografia = perfil.get('biography')  # Biografia
categoria = perfil.get('category_name')  # Categoria (Comedian)

# Extraindo os links da bio
links_bio = perfil.get('bio_links', [])
if links_bio:
    primeiro_link_titulo = links_bio[0].get('title')
    primeiro_link_url = links_bio[0].get('url')
else:
    primeiro_link_titulo = None
    primeiro_link_url = None

# Extraindo o número de seguidores e seguindo
seguidores_num = perfil.get('follower_count')  # Número de seguidores
seguindo_num = perfil.get('following_count')  # Número de pessoas seguidas

# Extraindo a URL da foto de perfil em alta resolução
foto_perfil = perfil.get('hd_profile_pic_versions')  # URL da foto de perfil em HD

# Extraindo a quantidade de posts
quantidade_posts = perfil.get('media_count')  # Quantidade de posts

# Verificação do perfil (se é verificado)
verificacao_perfil = perfil.get('is_verified')  # Verificado ou não

# Link do Threads.
threads = perfil.get('threads_profile_glyph_url')

# Exibindo as informações
print(f"Nome: {nome_perfil}")
print(f"ID: {id_perfil}")
print(f"Biografia: {biografia}")
print(f"Categoria: {categoria}")
print(f"Primeiro Link na Bio: {primeiro_link_titulo} - {primeiro_link_url}")
print(f"Seguidores: {seguidores_num}")
print(f"Seguindo: {seguindo_num}")
print(f"Foto de Perfil (HD): {foto_perfil}")
print(f"Quantidade de Posts: {quantidade_posts}")
print(f"Verificado: {verificacao_perfil}")
print(f"Threads: {threads}")
# Out:
# Nome: Marcito Castro
# ID: 482001976
# Biografia: 🎤 Comediante estandart
# ✊🏻 Compre no Sarandi ✊🏻
# 📥 @artistaria
# Categoria: None
# Primeiro Link na Bio: 🎭 INGRESSOS - https://onne.link/respeitavila
# Seguidores: 818737
# Seguindo: 3686
# Foto de Perfil (HD): [{'height': 320, 'url': 'https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s320x320&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYCYj7ew_DO7avu0M9ia37etJqif5h_8pC1h21f1O6N_hA&oe=66EBAE67&_nc_sid=1e20d2', 'width': 320}, {'height': 640, 'url': 'https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s640x640&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYDrxUrZLJaCZ9N3Rmk72QIhHcZtnarR4WMeewderOKk1g&oe=66EBAE67&_nc_sid=1e20d2', 'width': 640}]
# Quantidade de Posts: 4053
# Verificado: True
# Threads: https://www.threads.net/@marcitocastro?modal=true&xmt=AQGzNddeZfnEwf-ECwSZaeT-GhP24TV7QSk3dtAscYFyS7k

# %%
# Obtendo os dados do perfil da resposta da API.
# Extraindo informaçõs específicas do perfil.

perfil = response_instagram.get("data")

nome_perfil = perfil.get('full_name')
id = perfil.get('id')
biografia = perfil.get('biography')
categoria = perfil.get('category')
links_bio = perfil.get('bio_links', {}.get('url'))
seguidores_num = perfil.get('follower_count')
seguindo_num = perfil.get('following_count')
foto_perfil = perfil.get('hd_profile_pic_versions')

quantidade_posts = perfil.get('media_count')
vericacao_perfil = perfil.get('is_verified')
threads = perfil.get('threads_profile_glyph_url')

# Definindo o esquema do DataFrame com os tipos de dados esperados

schema = StructType([
  StructField("nome_perfil", StringType(), nullable=False),
  StructField("id", StringType(), nullable=True),
  StructField("biografia", StringType(), nullable=True),
  StructField("categoria", StringType(), nullable=True),
  StructField("links_bio", StringType(), nullable=True),
  StructField("seguidores_num", StringType(), nullable=True),
  StructField("seguindo_num", StringType(), nullable=True),
  StructField("foto_perfil", StringType(), nullable=True),
  StructField("quantidade_posts", StringType(), nullable=True),
  StructField("vericacao_perfil", StringType(), nullable=True),
  StructField("threads", StringType(), nullable=True),

])

print(type(nome_perfil))

# Preparando os dados para criar o DataFrame.

data = [(nome_perfil,id,biografia,categoria,links_bio,seguidores_num,seguindo_num,foto_perfil,quantidade_posts,vericacao_perfil,threads)]
print(data)

df = spark.createDataFrame(data, schema=schema)

# Criando o DataFrame.
# df = spark.createDataFrame(data, columns)

df = df.withColumn('ts_exec', F.current_timestamp())

# Mostrando o DataFrame.
df.write.partitionBy("nome_perfil","ts_exec").mode("append").format('parquet').save('/content/Datalake/Instagram/Perfil_v2/')

df.show(truncate=False)
# Out:
# <class 'str'>
# [('Marcito Castro', '482001976', '🎤 Comediante estandart\n✊🏻 Compre no Sarandi ✊🏻\n📥 @artistaria', 'Comedian', [{'link_id': '18011225563703977', 'url': 'https://onne.link/respeitavila', 'lynx_url': 'https://l.instagram.com/?u=https%3A%2F%2Fonne.link%2Frespeitavila&e=AT2YwieySIT0QNP_8whcD_5xi9madlkCoE0kdtnOkxtJNERiX2-s4qKJjvqI-bME5ikYxf_0kgAfoHj1Ib-AlfWdn9svSmfokCfwz7Q', 'link_type': 'external', 'title': '🎭 INGRESSOS', 'image_url': '', 'icon_url': '', 'is_pinned': False, 'is_verified': False, 'open_external_url_with_in_app_browser': True}], 818737, 3686, [{'height': 320, 'url': 'https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s320x320&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYCYj7ew_DO7avu0M9ia37etJqif5h_8pC1h21f1O6N_hA&oe=66EBAE67&_nc_sid=1e20d2', 'width': 320}, {'height': 640, 'url': 'https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s640x640&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYDrxUrZLJaCZ9N3Rmk72QIhHcZtnarR4WMeewderOKk1g&oe=66EBAE67&_nc_sid=1e20d2', 'width': 640}], 4053, True, 'https://www.threads.net/@marcitocastro?modal=true&xmt=AQGzNddeZfnEwf-ECwSZaeT-GhP24TV7QSk3dtAscYFyS7k')]
# +--------------+---------+----------------------------------------------------------------+---------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------------------------------------------------------------------+-----------------------+
# |nome_perfil   |id       |biografia                                                       |categoria|links_bio                                                                                                                                                                                                                                                                                                                                                                                             |seguidores_num|seguindo_num|foto_perfil                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |quantidade_posts|vericacao_perfil|threads                                                                                              |ts_exec                |
# +--------------+---------+----------------------------------------------------------------+---------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------------------------------------------------------------------+-----------------------+
# |Marcito Castro|482001976|🎤 Comediante estandart
# ✊🏻 Compre no Sarandi ✊🏻
# 📥 @artistaria|Comedian |[{icon_url=, link_type=external, open_external_url_with_in_app_browser=true, image_url=, lynx_url=https://l.instagram.com/?u=https%3A%2F%2Fonne.link%2Frespeitavila&e=AT2YwieySIT0QNP_8whcD_5xi9madlkCoE0kdtnOkxtJNERiX2-s4qKJjvqI-bME5ikYxf_0kgAfoHj1Ib-AlfWdn9svSmfokCfwz7Q, title=🎭 INGRESSOS, is_verified=false, url=https://onne.link/respeitavila, link_id=18011225563703977, is_pinned=false}]|818737        |3686        |[{width=320, url=https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s320x320&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYCYj7ew_DO7avu0M9ia37etJqif5h_8pC1h21f1O6N_hA&oe=66EBAE67&_nc_sid=1e20d2, height=320}, {width=640, url=https://instagram.fphl1-1.fna.fbcdn.net/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_s640x640&_nc_ht=instagram.fphl1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgH2XwTX&_nc_gid=04c7c0b6f29f4f98873b7c70eeb14734&edm=AEF8tYYBAAAA&ccb=7-5&oh=00_AYDrxUrZLJaCZ9N3Rmk72QIhHcZtnarR4WMeewderOKk1g&oe=66EBAE67&_nc_sid=1e20d2, height=640}]|4053            |true            |https://www.threads.net/@marcitocastro?modal=true&xmt=AQGzNddeZfnEwf-ECwSZaeT-GhP24TV7QSk3dtAscYFyS7k|2024-09-14 20:14:34.836|
# +--------------+---------+----------------------------------------------------------------+---------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+----------------+-----------------------------------------------------------------------------------------------------+-----------------------+

# %% [markdown]
# ### Extraindo Postagens / Get Posts

# %%
# Definindo parâmetro de consulta para API.
# Definindo método da API para chamar informações.


querystring = {"username_or_id": influencer,"count":"12"}

method = 'user_posts'

response = requests.get(f'{url}{method}',
                          headers=headers,
                          params=querystring)

response_instagram = response.json()

# %%
response_instagram
# Out:
# {'data': {'profile_grid_items': None,
#   'profile_grid_items_cursor': None,
#   'pinned_profile_grid_items_ids': None,
#   'num_results': 12,
#   'more_available': True,
#   'items': [{'taken_at': 1725301568,
#     'pk': '3448401954307684253',
#     'id': '3448401954307684253_482001976',
#     'fbid': '18433122457066480',
#     'device_timestamp': 172530125116770,
#     'caption_is_edited': False,
#     'strong_id__': '3448401954307684253_482001976',
#     'deleted_reason': 0,
#     'has_shared_to_fb': 0,
#     'has_delayed_metadata': False,
#     'is_quiet_post': False,
#     'mezql_token': '',
#     'share_count_disabled': False,
#     'is_visual_reply_commenter_notice_enabled': True,
#     'like_and_view_counts_disabled': False,
#     'is_post_live_clips_media': False,
#     'comment_threading_enabled': True,
#     'is_unified_video': False,
#     'commerciality_status': 'not_commercial',
#     'client_cache_key': 'MzQ0ODQwMTk1NDMwNzY4NDI1Mw==.3',
#     'integrity_review_decision': 'pending',
#     'should_request_ads': False,
#     'is_reshare_of_text_post_app_media_in_ig': False,
#     'has_privately_liked': False,
#     'filter_type': 0,
#     'usertags': {'in': [{'categories': None,
#        'duration_in_video_in_sec': None,
#        'position': [0.2178294574, 0.0275193798],
#        'show_category_of_user': False,
#        'start_time_in_video_in_sec': None,
#        'user': {'pk': '283038768',
#         'pk_id': '283038768',
#         'id': '283038768',
#         'full_name': 'Artistaria Produtora de Humor',
#         'is_private': False,
#         'strong_id__': '283038768',
#         'username': 'artistaria',
#         'is_verified': False,
#         'profile_pic_id': '3237585762920388942_283038768',
#         'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/402461497_693925159360802_1610538001837494238_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=5XLA6oCs_E8Q7kNvgHXvS74&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYC0AqSdKaM2u-Lc_wuOqVsdYUTnh8LeLOW91sQg1GXb_A&oe=66EBBFDF&_nc_sid=b41fef'}}]},
#     'photo_of_you': False,
#     'can_see_insights_as_brand': False,
#     'media_type': 1,
#     'code': 'C_bL06ZRbed',
#     'caption': {'bit_flags': 0,
#      'created_at': 1725301569,
#      'created_at_utc': 1725301569,
#      'did_report_as_spam': False,
#      'is_ranked_comment': False,
#      'pk': '18433122463066480',
#      'share_enabled': False,
#      'content_type': 'comment',
#      'media_id': '3448401954307684253',
#      'status': 'Active',
#      'type': 1,
#      'user_id': '482001976',
#      'strong_id__': '18433122463066480',
#      'has_translation': True,
#      'text': 'TESTANDO PIADAS - 4ª edição 💃🏻\n.\nAs três primeiras edições do “Testando Piadas” na Amrigs foram um sucesso. E vamo de novo.\nPra quem não tá ligado, sempre no último domingo de cada mês eu tô lá testando piadas novos e trazendo comigo uns cpx pra também testar as deles.\nDessa vez, 29 DE SETEMBRO (19h), vou estar com a @ursamalgarizi e o @sortiagao no elenco.\nE de quebra tem uma canja do Diego Capela, o @guridafarmacia \n.\nVAI DÁ BOM DE NOVO, então garante teu ingresso e vamo colar junto lá com a gente \U0001faf6🏻🥳\n.\nINGRESSOS nos STORIES e na BIO 🚀',
#      'user': {'pk': '482001976',
#       'pk_id': '482001976',
#       'id': '482001976',
#       'full_name': 'Marcito Castro',
#       'is_private': False,
#       'is_unpublished': False,
#       'strong_id__': '482001976',
#       'fbid_v2': '17841400539287531',
#       'username': 'marcitocastro',
#       'is_verified': True,
#       'profile_pic_id': '3436382941194761236_482001976',
#       'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef'},
#      'is_covered': False,
#      'private_reply_status': 0},
#     'fundraiser_tag': {'has_standalone_fundraiser': False},
#     'sharing_friction_info': {'bloks_app_url': None,
#      'should_have_sharing_friction': False,
#      'sharing_friction_payload': None},
#     'timeline_pinned_user_ids': [482001976],
#     'accessibility_caption': 'Photo by Marcito Castro in AMRIGS Associação Médica do RS with @artistaria. May be an image of 3 people, poster, top and text.',
#     'original_media_has_visual_reply_media': False,
#     'fb_user_tags': {'in': []},
#     'coauthor_producers': [],
#     'coauthor_producer_can_see_organic_insights': False,
#     'invited_coauthor_producers': [],
#     'mashup_info': {'mashups_allowed': True,
#      'is_reuse_allowed': True,
#      'can_toggle_mashups_allowed': False,
#      'has_been_mashed_up': False,
#      'is_light_weight_check': True,
#      'is_light_weight_reuse_allowed_check': False,
#      'formatted_mashups_count': None,
#      'original_media': None,
#      'privacy_filtered_mashups_media_count': None,
#      'non_privacy_filtered_mashups_media_count': None,
#      'mashup_type': None,
#      'is_creator_requesting_mashup': False,
#      'has_nonmimicable_additional_audio': False,
#      'is_pivot_page_available': False},
#     'is_in_profile_grid': False,
#     'profile_grid_control_enabled': False,
#     'user': {'fbid_v2': '17841400539287531',
#      'feed_post_reshare_disabled': False,
#      'full_name': 'Marcito Castro',
#      'id': '482001976',
#      'is_private': False,
#      'is_unpublished': False,
#      'pk': '482001976',
#      'pk_id': '482001976',
#      'show_account_transparency_details': True,
#      'strong_id__': '482001976',
#      'third_party_downloads_enabled': 1,
#      'account_type': 3,
#      'account_badges': [],
#      'fan_club_info': {'autosave_to_exclusive_highlight': None,
#       'connected_member_count': None,
#       'fan_club_id': None,
#       'fan_club_name': None,
#       'has_enough_subscribers_for_ssc': None,
#       'is_fan_club_gifting_eligible': None,
#       'is_fan_club_referral_eligible': None,
#       'subscriber_count': None,
#       'fan_consideration_page_revamp_eligiblity': None},
#      'friendship_status': {'following': False,
#       'is_bestie': False,
#       'is_feed_favorite': False,
#       'is_restricted': False},
#      'has_anonymous_profile_picture': False,
#      'is_favorite': False,
#      'is_verified': True,
#      'profile_pic_id': '3436382941194761236_482001976',
#      'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef',
#      'transparency_product_enabled': False,
#      'username': 'marcitocastro',
#      'can_see_quiet_post_attribution': True},
#     'owner': {'fbid_v2': '17841400539287531',
#      'feed_post_reshare_disabled': False,
#      'full_name': 'Marcito Castro',
#      'id': '482001976',
#      'is_private': False,
#      'is_unpublished': False,
#      'pk': '482001976',
#      'pk_id': '482001976',
#      'show_account_transparency_details': True,
#      'strong_id__': '482001976',
#      'third_party_downloads_enabled': 1,
#      'account_type': 3,
#      'account_badges': [],
#      'fan_club_info': {'autosave_to_exclusive_highlight': None,
#       'connected_member_count': None,
#       'fan_club_id': None,
#       'fan_club_name': None,
#       'has_enough_subscribers_for_ssc': None,
#       'is_fan_club_gifting_eligible': None,
#       'is_fan_club_referral_eligible': None,
#       'subscriber_count': None,
#       'fan_consideration_page_revamp_eligiblity': None},
#      'friendship_status': {'following': False,
#       'is_bestie': False,
#       'is_feed_favorite': False,
#       'is_restricted': False},
#      'has_anonymous_profile_picture': False,
#      'is_favorite': False,
#      'is_verified': True,
#      'profile_pic_id': '3436382941194761236_482001976',
#      'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef',
#      'transparency_product_enabled': False,
#      'username': 'marcitocastro',
#      'can_see_quiet_post_attribution': True},
#     'image_versions2': {'candidates': [{'width': 1080,
#        'height': 1346,
#        'url': 'https://scontent-iad3-2.cdninstagram.com/v/t51.29350-15/457666545_1031201388485124_4865510190400477601_n.jpg?stp=dst-jpg_e35_p1080x1080&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ3eDE2Nzkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=100&_nc_ohc=9WLgpWPU3HUQ7kNvgEYKhrV&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzQ0ODQwMTk1NDMwNzY4NDI1Mw%3D%3D.3-ccb7-5&oh=00_AYCqVOcQTMMVBcbKXDIPewfAFE_Q6LaTAPsACftlhh-Law&oe=66EBB9DF&_nc_sid=b41fef',
#        'scans_profile': 'e35'},
#       {'width': 360,
#        'height': 449,
#        'url': 'https://scontent-iad3-2.cdninstagram.com/v/t51.29350-15/457666545_1031201388485124_4865510190400477601_n.jpg?stp=dst-jpg_e35_p360x360&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ3eDE2Nzkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=100&_nc_ohc=9WLgpWPU3HUQ7kNvgEYKhrV&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzQ0ODQwMTk1NDMwNzY4NDI1Mw%3D%3D.3-ccb7-5&oh=00_AYB4NpS4p4Xt_i-Q5FKFovGtQFmjlU9-D3Ebf1n21k-6pg&oe=66EBB9DF&_nc_sid=b41fef',
#        'scans_profile': 'e35'}]},
#     'original_width': 1347,
#     'original_height': 1679,
#     'media_notes': {'items': []},
#     'enable_media_notes_production': False,
#     'product_type': 'feed',
#     'is_paid_partnership': False,
#     'location': {'address': 'Avenida Ipiranga, 5311 - Bairro Partenon',
#      'city': 'Porto Alegre',
#      'external_source': 'facebook_places',
#      'facebook_places_id': '229771203774418',
#      'has_viewer_saved': False,
#      'is_eligible_for_guides': False,
#      'lat': -30.058574929508,
#      'lng': -51.185319291803,
#      'name': 'AMRIGS Associação Médica do RS',
#      'pk': '5541920',
#      'short_name': 'AMRIGS Associação Médica do RS'},
#     'music_metadata': {'audio_type': 'licensed_music',
#      'music_canonical_id': '18125084734116075',
#      'pinned_media_ids': [],
#      'music_info': {'music_canonical_id': None,
#       'music_asset_info': {'allows_saving': True,
#        'artist_id': '350140858912556',
#        'audio_asset_id': '2246287992155414',
#        'audio_cluster_id': '401587117238390',
#        'cover_artwork_thumbnail_uri': 'https://scontent-iad3-1.xx.fbcdn.net/v/t39.30808-6/427531200_3514256588884515_2874551193749367387_n.jpg?stp=dst-jpg_s168x128&_nc_cat=102&ccb=1-7&_nc_sid=2f2557&_nc_ohc=ijs82cFz3VQQ7kNvgG45YoD&_nc_ad=z-m&_nc_cid=0&_nc_ht=scontent-iad3-1.xx&_nc_gid=A7mXzWhabDQU8PbHYIz_LSJ&oh=00_AYD7bJBG5YYmHTyENckNzq0MsrKJmVqpLNBOkrAV6MabfQ&oe=66EBC3E0',
#        'cover_artwork_uri': 'https://scontent-iad3-1.xx.fbcdn.net/v/t39.30808-6/427531200_3514256588884515_2874551193749367387_n.jpg?stp=dst-jpg_s168x128&_nc_cat=102&ccb=1-7&_nc_sid=2f2557&_nc_ohc=ijs82cFz3VQQ7kNvgG45YoD&_nc_ad=z-m&_nc_cid=0&_nc_ht=scontent-iad3-1.xx&_nc_gid=A7mXzWhabDQU8PbHYIz_LSJ&oh=00_AYD7bJBG5YYmHTyENckNzq0MsrKJmVqpLNBOkrAV6MabfQ&oe=66EBC3E0',
#        'dark_message': None,
#        'dash_manifest': '<?xml version="1.0" encoding="UTF-8"?>\n<MPD xmlns="urn:mpeg:dash:schema:mpd:2011" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="urn:mpeg:dash:schema:mpd:2011 DASH-MPD.xsd" profiles="urn:mpeg:dash:profile:isoff-on-demand:2011" minBufferTime="PT2S" type="static" mediaPresentationDuration="PT195.2933349609375S"><Period id="0" duration="PT195.2933349609375S"><AdaptationSet id="0" contentType="audio" subsegmentAlignment="true"><Representation id="2511690012350747a" bandwidth="49255" codecs="mp4a.40.5" mimeType="audio/mp4" FBAvgBitrate="49255" audioSamplingRate="44100" FBDefaultQuality="1"><AudioChannelConfiguration schemeIdUri="urn:mpeg:dash:23003:3:audio_channel_configuration:2011" value="2"/><BaseURL>https://scontent-iad3-1.xx.fbcdn.net/o1/v/t2/f2/m69/An8PfwXdS4yHCH6L9oEfXrVJ2VA4OO4RNwbWQGj5o_3tfzRTTgiP4TsvFCU3Q-hfGYuylNTjprTDGrMFn0ART6M.mp4?efg=eyJvaWxfdXJsZ2VuX2FwcF9pZCI6MjU2MjgxMDQwNTU4LCJjbGllbnRfbmFtZSI6InVua25vd24iLCJ2aWRlb19pZCI6bnVsbCwidmVuY29kZV90YWciOiJkYXNoX2F1ZGlvX2FhY3BfNDhfZnJhZ18yX2F1ZGlvIn0&amp;_nc_ht=scontent-iad3-1.xx.fbcdn.net&amp;_nc_cat=100&amp;strext=1&amp;ccb=9-4&amp;oh=00_AYA71GYCghbvqi_Y_JwBhsiDl1sktDG3Zr7v2CO49r6sFg&amp;oe=66E7B539&amp;_nc_sid=9ca052</BaseURL><SegmentBase indexRange="817-2024" timescale="44100"><Initialization range="0-816"/></SegmentBase></Representation></AdaptationSet></Period></MPD>\n',
#        'display_artist': 'Joey Scarbury',
#        'duration_in_ms': 195293,
#        'fast_start_progressive_download_url': 'https://scontent-iad3-1.xx.fbcdn.net/o1/v/t39.12897-2/f2/m69/An90UoXedeEkyNfNw2qbB-FPVyMF1mOU5nXbsGn9BTyYiowWzt-NVPCVc0QJV9QgMW-1XmluuebiHbvj5IFWVPs.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6Inhwdl9wcm9ncmVzc2l2ZS5BVURJT19PTkxZLi5DMy4wLnByb2dyZXNzaXZlX2F1ZGlvX2FhY3BfNDhfZnJhZ18yX2F1ZGlvIn0&_nc_ht=scontent-iad3-1.xx.fbcdn.net&_nc_cat=101&strext=1&ccb=9-4&oh=00_AYD4xsJ0mYa8b1Cj7JZk8Y1XcmWk-v-2n2T2cuIb0MypJQ&oe=66EB9982&_nc_sid=ec5945',
#        'has_lyrics': True,
#        'highlight_start_times_in_ms': [31500, 13500, 47500],
#        'id': '2246287992155414',
#        'ig_username': None,
#        'is_eligible_for_audio_effects': False,
#        'is_explicit': False,
#        'progressive_download_url': 'https://scontent-iad3-1.xx.fbcdn.net/o1/v/t39.12897-2/f2/m69/An90UoXedeEkyNfNw2qbB-FPVyMF1mOU5nXbsGn9BTyYiowWzt-NVPCVc0QJV9QgMW-1XmluuebiHbvj5IFWVPs.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6Inhwdl9wcm9ncmVzc2l2ZS5BVURJT19PTkxZLi5DMy4wLnByb2dyZXNzaXZlX2F1ZGlvX2FhY3BfNDhfZnJhZ18yX2F1ZGlvIn0&_nc_ht=scontent-iad3-1.xx.fbcdn.net&_nc_cat=101&strext=1&ccb=9-4&oh=00_AYD4xsJ0mYa8b1Cj7JZk8Y1XcmWk-v-2n2T2cuIb0MypJQ&oe=66EB9982&_nc_sid=ec5945',
#        'reactive_audio_download_url': None,
#        'sanitized_title': None,
#        'subtitle': '',
#        'title': 'Believe It or Not (Theme from "Greatest American Hero")',
#        'web_30s_preview_download_url': None,
#        'is_eligible_for_vinyl_sticker': True},
#       'music_consumption_info': {'allow_media_creation_with_music': True,
#        'audio_asset_start_time_in_ms': 31446,
#        'contains_lyrics': None,
#        'derived_content_id': None,
#        'display_labels': None,
#        'formatted_clips_media_count': None,
#        'ig_artist': None,
#        'is_bookmarked': False,
#        'is_trending_in_clips': False,
#        'overlap_duration_in_ms': 90000,
#        'placeholder_profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.12442-15/43985629_311105916145351_58064759811405776_n.jpg?_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=107&_nc_ohc=7rmGcllVUggQ7kNvgFwSdV7&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApAAAAAA&ccb=7-5&oh=00_AYBklExfx9fXWgSxkCatc7TFbSo5g8M96V65Gzjp-0G9xg&oe=66EB94FD&_nc_sid=b41fef',
#        'should_allow_music_editing': False,
#        'should_mute_audio': False,
#        'should_mute_audio_reason': '',
#        'should_mute_audio_reason_type': None,
#        'should_render_soundwave': False,
#        'trend_rank': None,
#        'previous_trend_rank': None,
#        'audio_filter_infos': [],
#        'audio_muting_info': {'mute_audio': False,
#         'mute_reason_str': '',
#         'allow_audio_editing': False,
#         'show_muted_audio_toast': False}}},
#      'original_sound_info': None},
#     'social_context': [],
#     'organic_tracking_token': '',
#     'ig_media_sharing_disabled': False,
#     'boost_unavailable_identifier': None,
#     'boost_unavailable_reason': None,
#     'boost_unavailable_reason_v2': [],
#     'lng': -51.185319291803,
#     'lat': -30.058574929508,
#     'subscribe_cta_visible': False,
#     'is_cutout_sticker_allowed': True,
#     'gen_ai_detection_method': {'detection_method': 'NONE'},
#     'fb_aggregated_like_count': 0,
#     'fb_aggregated_comment_count': 0,
#     'has_high_risk_gen_ai_inform_treatment': False,
#     'open_carousel_show_follow_button': False,
#     'is_tagged_media_shared_to_viewer_profile_grid': False,
#     'should_show_author_pog_for_tagged_media_shared_to_profile_grid': False,
#     'is_eligible_for_media_note_recs_nux': False,
#     'is_social_ufi_disabled': False,
#     'is_eligible_for_meta_ai_share': False,
#     'can_reply': False,
#     'can_view_more_preview_comments': False,
#     'preview_comments': [],
#     'comment_count': 21,
#     'hide_view_all_comment_entrypoint': False,
#     'inline_composer_display_condition': 'impression_trigger',
#     'inline_composer_imp_trigger_time': 5,
#     'is_comments_gif_composer_enabled': True,
#     'comment_inform_treatment': {'action_type': None,
#      'should_have_inform_treatment': False,
#      'text': '',
#      'url': None},
#     'has_liked': False,
#     'like_count': 567,
#     'facepile_top_likers': [],
#     'top_likers': [],
#     'clips_tab_pinned_user_ids': [],
#     'can_viewer_save': True,
#     'can_viewer_reshare': True,
#     'shop_routing_user_id': None,
#     'is_organic_product_tagging_eligible': False,
#     'igbio_product': None,
#     'featured_products': [],
#     'product_suggestions': [],
#     'is_reuse_allowed': True,
#     'has_more_comments': True,
#     'max_num_visible_preview_comments': 2,
#     'explore_hide_comments': False,
#     'is_open_to_public_submission': False},
#    {'taken_at': 1724880033,
#     'pk': '3444865860697304235',
#     'id': '3444865860697304235_482001976',
#     'fbid': '18036550172482371',
#     'device_timestamp': 1724879928670751,
#     'caption_is_edited': False,
#     'strong_id__': '3444865860697304235_482001976',
#     'deleted_reason': 0,
#     'has_shared_to_fb': 0,
#     'has_delayed_metadata': False,
#     'is_quiet_post': False,
#     'mezql_token': '',
#     'share_count_disabled': False,
#     'is_visual_reply_commenter_notice_enabled': True,
#     'like_and_view_counts_disabled': False,
#     'is_post_live_clips_media': False,
#     'comment_threading_enabled': True,
#     'is_unified_video': False,
#     'commerciality_status': 'not_commercial',
#     'client_cache_key': 'MzQ0NDg2NTg2MDY5NzMwNDIzNQ==.3',
#     'integrity_review_decision': 'pending',
#     'should_request_ads': False,
#     'is_reshare_of_text_post_app_media_in_ig': False,
#     'has_privately_liked': False,
#     'filter_type': 0,
#     'usertags': {'in': [{'categories': None,
#        'duration_in_video_in_sec': None,
#        'position': [0.5, 0.5],
#        'show_category_of_user': False,
#        'start_time_in_video_in_sec': None,
#        'user': {'pk': '283038768',
#         'pk_id': '283038768',
#         'id': '283038768',
#         'full_name': 'Artistaria Produtora de Humor',
#         'is_private': False,
#         'strong_id__': '283038768',
#         'username': 'artistaria',
#         'is_verified': False,
#         'profile_pic_id': '3237585762920388942_283038768',
#         'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/402461497_693925159360802_1610538001837494238_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=5XLA6oCs_E8Q7kNvgHXvS74&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYC0AqSdKaM2u-Lc_wuOqVsdYUTnh8LeLOW91sQg1GXb_A&oe=66EBBFDF&_nc_sid=b41fef'}}]},
#     'photo_of_you': False,
#     'can_see_insights_as_brand': False,
#     'media_type': 1,
#     'code': 'C_Onz-lu6yr',
#     'caption': {'bit_flags': 0,
#      'created_at': 1724880034,
#      'created_at_utc': 1724880034,
#      'did_report_as_spam': False,
#      'is_ranked_comment': False,
#      'pk': '18036550175482371',
#      'share_enabled': False,
#      'content_type': 'comment',
#      'media_id': '3444865860697304235',
#      'status': 'Active',
#      'type': 1,
#      'user_id': '482001976',
#      'strong_id__': '18036550175482371',
#      'has_translation': True,
#      'text': 'AGENDINHA REGIONAL RAIZ DE SETEMBRO ❤️❤️🌹\n.\nIngresso nos stories e na bio 🚀',
#      'user': {'pk': '482001976',
#       'pk_id': '482001976',
#       'id': '482001976',
#       'full_name': 'Marcito Castro',
#       'is_private': False,
#       'is_unpublished': False,
#       'strong_id__': '482001976',
#       'fbid_v2': '17841400539287531',
#       'username': 'marcitocastro',
#       'is_verified': True,
#       'profile_pic_id': '3436382941194761236_482001976',
#       'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef'},
#      'is_covered': False,
#      'private_reply_status': 0},
#     'fundraiser_tag': {'has_standalone_fundraiser': False},
#     'sharing_friction_info': {'bloks_app_url': None,
#      'should_have_sharing_friction': False,
#      'sharing_friction_payload': None},
#     'timeline_pinned_user_ids': [482001976],
#     'accessibility_caption': 'Photo shared by Marcito Castro on August 28, 2024 tagging @artistaria. May be an image of \u200e1 person, poster, calendar, top and \u200etext that says "\u200eศวาบตา AGENDA SETEME חר 02 ButecoComedyBar Buteco Comedy Bar CANOAS, RS 11 SÃO LEOPOLDO, RS São eo Comedy 12 Cine Arcoplex CACHOEIRINHA, RS Shopping do Vale 13 GUAÍBA, RS Auditório Ulbra 25 São Lẽo Comedy SÃO LEOPOLDO, RS 26 NOVO HAMBURGO, RS Buteco Comedy NH SANTA CRUZ DO SUL, RS TeatroMaua Mauã Teatro 29 PORTO ALEGRE, RS Teatro AMRIGS 30 ButecoComedyB Buteco Comedy Bar CANOAS, RS 27 Artistaria WWW.ARTISTARIA.COM.ER\u200e"\u200e\u200e.',
#     'original_media_has_visual_reply_media': False,
#     'fb_user_tags': {'in': []},
#     'coauthor_producers': [{'pk': '283038768',
#       'pk_id': '283038768',
#       'id': '283038768',
#       'full_name': 'Artistaria Produtora de Humor',
#       'is_private': False,
#       'strong_id__': '283038768',
#       'username': 'artistaria',
#       'is_verified': False,
#       'profile_pic_id': '3237585762920388942_283038768',
#       'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/402461497_693925159360802_1610538001837494238_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=5XLA6oCs_E8Q7kNvgHXvS74&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYC0AqSdKaM2u-Lc_wuOqVsdYUTnh8LeLOW91sQg1GXb_A&oe=66EBBFDF&_nc_sid=b41fef'}],
#     'coauthor_producer_can_see_organic_insights': False,
#     'invited_coauthor_producers': [],
#     'mashup_info': {'mashups_allowed': True,
#      'is_reuse_allowed': True,
#      'can_toggle_mashups_allowed': False,
#      'has_been_mashed_up': False,
#      'is_light_weight_check': True,
#      'is_light_weight_reuse_allowed_check': False,
#      'formatted_mashups_count': None,
#      'original_media': None,
#      'privacy_filtered_mashups_media_count': None,
#      'non_privacy_filtered_mashups_media_count': None,
#      'mashup_type': None,
#      'is_creator_requesting_mashup': False,
#      'has_nonmimicable_additional_audio': False,
#      'is_pivot_page_available': False},
#     'is_in_profile_grid': False,
#     'profile_grid_control_enabled': False,
#     'user': {'fbid_v2': '17841400539287531',
#      'feed_post_reshare_disabled': False,
#      'full_name': 'Marcito Castro',
#      'id': '482001976',
#      'is_private': False,
#      'is_unpublished': False,
#      'pk': '482001976',
#      'pk_id': '482001976',
#      'show_account_transparency_details': True,
#      'strong_id__': '482001976',
#      'third_party_downloads_enabled': 1,
#      'account_type': 3,
#      'account_badges': [],
#      'fan_club_info': {'autosave_to_exclusive_highlight': None,
#       'connected_member_count': None,
#       'fan_club_id': None,
#       'fan_club_name': None,
#       'has_enough_subscribers_for_ssc': None,
#       'is_fan_club_gifting_eligible': None,
#       'is_fan_club_referral_eligible': None,
#       'subscriber_count': None,
#       'fan_consideration_page_revamp_eligiblity': None},
#      'friendship_status': {'following': False,
#       'is_bestie': False,
#       'is_feed_favorite': False,
#       'is_restricted': False},
#      'has_anonymous_profile_picture': False,
#      'is_favorite': False,
#      'is_verified': True,
#      'profile_pic_id': '3436382941194761236_482001976',
#      'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef',
#      'transparency_product_enabled': False,
#      'username': 'marcitocastro',
#      'can_see_quiet_post_attribution': True},
#     'owner': {'fbid_v2': '17841400539287531',
#      'feed_post_reshare_disabled': False,
#      'full_name': 'Marcito Castro',
#      'id': '482001976',
#      'is_private': False,
#      'is_unpublished': False,
#      'pk': '482001976',
#      'pk_id': '482001976',
#      'show_account_transparency_details': True,
#      'strong_id__': '482001976',
#      'third_party_downloads_enabled': 1,
#      'account_type': 3,
#      'account_badges': [],
#      'fan_club_info': {'autosave_to_exclusive_highlight': None,
#       'connected_member_count': None,
#       'fan_club_id': None,
#       'fan_club_name': None,
#       'has_enough_subscribers_for_ssc': None,
#       'is_fan_club_gifting_eligible': None,
#       'is_fan_club_referral_eligible': None,
#       'subscriber_count': None,
#       'fan_consideration_page_revamp_eligiblity': None},
#      'friendship_status': {'following': False,
#       'is_bestie': False,
#       'is_feed_favorite': False,
#       'is_restricted': False},
#      'has_anonymous_profile_picture': False,
#      'is_favorite': False,
#      'is_verified': True,
#      'profile_pic_id': '3436382941194761236_482001976',
#      'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef',
#      'transparency_product_enabled': False,
#      'username': 'marcitocastro',
#      'can_see_quiet_post_attribution': True},
#     'image_versions2': {'candidates': [{'width': 1080,
#        'height': 1346,
#        'url': 'https://scontent-iad3-2.cdninstagram.com/v/t51.29350-15/457253650_430553743338917_8513078340794645965_n.jpg?stp=dst-jpg_e35_p1080x1080&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ3eDE2Nzkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=105&_nc_ohc=1PFgR2ZETzcQ7kNvgFvsO7v&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzQ0NDg2NTg2MDY5NzMwNDIzNQ%3D%3D.3-ccb7-5&oh=00_AYBjaUfHPfzY97lZ2Tx3sGjL3cWlqL_qmSKmkQ4vlCk8Og&oe=66EB9C40&_nc_sid=b41fef',
#        'scans_profile': 'e35'},
#       {'width': 360,
#        'height': 449,
#        'url': 'https://scontent-iad3-2.cdninstagram.com/v/t51.29350-15/457253650_430553743338917_8513078340794645965_n.jpg?stp=dst-jpg_e35_p360x360&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ3eDE2Nzkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=105&_nc_ohc=1PFgR2ZETzcQ7kNvgFvsO7v&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzQ0NDg2NTg2MDY5NzMwNDIzNQ%3D%3D.3-ccb7-5&oh=00_AYAmFzdcoAy1BuOfAQDHN2k8bhj8So2pka2ztxL0z5l-TA&oe=66EB9C40&_nc_sid=b41fef',
#        'scans_profile': 'e35'}]},
#     'original_width': 1347,
#     'original_height': 1679,
#     'media_notes': {'items': []},
#     'enable_media_notes_production': False,
#     'product_type': 'feed',
#     'is_paid_partnership': False,
#     'music_metadata': {'audio_type': 'licensed_music',
#      'music_canonical_id': '18155180899043026',
#      'pinned_media_ids': [],
#      'music_info': {'music_canonical_id': None,
#       'music_asset_info': {'allows_saving': True,
#        'artist_id': '2201655740048380',
#        'audio_asset_id': '766533184562629',
#        'audio_cluster_id': '2227879680811173',
#        'cover_artwork_thumbnail_uri': 'https://scontent-iad3-1.xx.fbcdn.net/v/t39.30808-6/426709789_2660314987464630_5996572380203920157_n.jpg?stp=dst-jpg_s168x128&_nc_cat=1&ccb=1-7&_nc_sid=2f2557&_nc_ohc=l2wEpfXOpAgQ7kNvgFmabEa&_nc_ad=z-m&_nc_cid=0&_nc_ht=scontent-iad3-1.xx&_nc_gid=A7mXzWhabDQU8PbHYIz_LSJ&oh=00_AYBYyt4qJ94h46Kr56d9X5Vwev98oOK8x2bbr-c33MSSDA&oe=66EBBCE0',
#        'cover_artwork_uri': 'https://scontent-iad3-1.xx.fbcdn.net/v/t39.30808-6/426709789_2660314987464630_5996572380203920157_n.jpg?stp=dst-jpg_s168x128&_nc_cat=1&ccb=1-7&_nc_sid=2f2557&_nc_ohc=l2wEpfXOpAgQ7kNvgFmabEa&_nc_ad=z-m&_nc_cid=0&_nc_ht=scontent-iad3-1.xx&_nc_gid=A7mXzWhabDQU8PbHYIz_LSJ&oh=00_AYBYyt4qJ94h46Kr56d9X5Vwev98oOK8x2bbr-c33MSSDA&oe=66EBBCE0',
#        'dark_message': None,
#        'dash_manifest': '<?xml version="1.0" encoding="UTF-8"?>\n<MPD xmlns="urn:mpeg:dash:schema:mpd:2011" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="urn:mpeg:dash:schema:mpd:2011 DASH-MPD.xsd" profiles="urn:mpeg:dash:profile:isoff-on-demand:2011" minBufferTime="PT2S" type="static" mediaPresentationDuration="PT197.93594360351562S"><Period id="0" duration="PT197.93594360351562S"><AdaptationSet id="0" contentType="audio" subsegmentAlignment="true"><Representation id="439718605304558a" bandwidth="49256" codecs="mp4a.40.5" mimeType="audio/mp4" FBAvgBitrate="49256" audioSamplingRate="44100" FBDefaultQuality="1"><AudioChannelConfiguration schemeIdUri="urn:mpeg:dash:23003:3:audio_channel_configuration:2011" value="2"/><BaseURL>https://scontent-iad3-1.xx.fbcdn.net/v/t39.12897-6/437491426_404112745822083_8049495828739084248_n.mp4?_nc_cat=1&amp;ccb=1-7&amp;_nc_sid=9a5d50&amp;efg=eyJ2ZW5jb2RlX3RhZyI6ImRhc2hfYXVkaW9fYWFjcF80OF9mcmFnXzJfYXVkaW8iLCJ2aWRlb19pZCI6bnVsbH0%3D&amp;_nc_ohc=jYhXrwRUiakQ7kNvgFnaChX&amp;_nc_ht=scontent-iad3-1.xx&amp;_nc_gid=A7mXzWhabDQU8PbHYIz_LSJ&amp;oh=00_AYBuzmKd1pAU2Fn8X15exRt_RB-LHQXEHHa4-McoGa8l9A&amp;oe=66EBA5C3</BaseURL><SegmentBase indexRange="817-2036" timescale="44100"><Initialization range="0-816"/></SegmentBase></Representation></AdaptationSet></Period></MPD>\n',
#        'display_artist': 'Carl Douglas',
#        'duration_in_ms': 197935,
#        'fast_start_progressive_download_url': 'https://scontent-iad3-1.xx.fbcdn.net/o1/v/t39.12897-2/f2/m69/An-4KkOC3VErcF0p3ub3c4Bl9laorz79gIYWE6Ztj6jXAZFkDS45vuz5eZVDPJ3pQiqS-_2juPsx1uf0ordtqe-4.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6Inhwdl9wcm9ncmVzc2l2ZS5BVURJT19PTkxZLi5DMy4wLnByb2dyZXNzaXZlX2F1ZGlvX2FhY3BfNDhfZnJhZ18yX2F1ZGlvIn0&_nc_ht=scontent-iad3-1.xx.fbcdn.net&_nc_cat=110&strext=1&ccb=9-4&oh=00_AYA0faENcM6qh6XZAg8axU9m_pb3TxrSz6QGJuxTktCNAw&oe=66EB9D42&_nc_sid=ec5945',
#        'has_lyrics': True,
#        'highlight_start_times_in_ms': [25000, 101500, 63500],
#        'id': '766533184562629',
#        'ig_username': None,
#        'is_eligible_for_audio_effects': True,
#        'is_explicit': False,
#        'progressive_download_url': 'https://scontent-iad3-1.xx.fbcdn.net/o1/v/t39.12897-2/f2/m69/An-4KkOC3VErcF0p3ub3c4Bl9laorz79gIYWE6Ztj6jXAZFkDS45vuz5eZVDPJ3pQiqS-_2juPsx1uf0ordtqe-4.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6Inhwdl9wcm9ncmVzc2l2ZS5BVURJT19PTkxZLi5DMy4wLnByb2dyZXNzaXZlX2F1ZGlvX2FhY3BfNDhfZnJhZ18yX2F1ZGlvIn0&_nc_ht=scontent-iad3-1.xx.fbcdn.net&_nc_cat=110&strext=1&ccb=9-4&oh=00_AYA0faENcM6qh6XZAg8axU9m_pb3TxrSz6QGJuxTktCNAw&oe=66EB9D42&_nc_sid=ec5945',
#        'reactive_audio_download_url': None,
#        'sanitized_title': None,
#        'subtitle': '',
#        'title': 'Kung Fu Fighting',
#        'web_30s_preview_download_url': None,
#        'is_eligible_for_vinyl_sticker': True},
#       'music_consumption_info': {'allow_media_creation_with_music': True,
#        'audio_asset_start_time_in_ms': 63178,
#        'contains_lyrics': None,
#        'derived_content_id': None,
#        'display_labels': None,
#        'formatted_clips_media_count': None,
#        'ig_artist': None,
#        'is_bookmarked': False,
#        'is_trending_in_clips': False,
#        'overlap_duration_in_ms': 30000,
#        'placeholder_profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.12442-15/43985629_311105916145351_58064759811405776_n.jpg?_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=107&_nc_ohc=7rmGcllVUggQ7kNvgFwSdV7&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApAAAAAA&ccb=7-5&oh=00_AYBklExfx9fXWgSxkCatc7TFbSo5g8M96V65Gzjp-0G9xg&oe=66EB94FD&_nc_sid=b41fef',
#        'should_allow_music_editing': False,
#        'should_mute_audio': False,
#        'should_mute_audio_reason': '',
#        'should_mute_audio_reason_type': None,
#        'should_render_soundwave': False,
#        'trend_rank': None,
#        'previous_trend_rank': None,
#        'audio_filter_infos': [],
#        'audio_muting_info': {'mute_audio': False,
#         'mute_reason_str': '',
#         'allow_audio_editing': False,
#         'show_muted_audio_toast': False}}},
#      'original_sound_info': None},
#     'social_context': [],
#     'organic_tracking_token': '',
#     'ig_media_sharing_disabled': False,
#     'boost_unavailable_identifier': None,
#     'boost_unavailable_reason': None,
#     'boost_unavailable_reason_v2': [],
#     'subscribe_cta_visible': False,
#     'is_cutout_sticker_allowed': True,
#     'gen_ai_detection_method': {'detection_method': 'NONE'},
#     'fb_aggregated_like_count': 0,
#     'fb_aggregated_comment_count': 0,
#     'has_high_risk_gen_ai_inform_treatment': False,
#     'collab_follow_button_info': {'show_follow_button': False,
#      'is_owner_in_author_exp': False},
#     'open_carousel_show_follow_button': False,
#     'is_tagged_media_shared_to_viewer_profile_grid': False,
#     'should_show_author_pog_for_tagged_media_shared_to_profile_grid': False,
#     'is_eligible_for_media_note_recs_nux': False,
#     'should_open_collab_bottomsheet_on_facepile_tap': False,
#     'is_social_ufi_disabled': False,
#     'is_eligible_for_meta_ai_share': False,
#     'can_reply': False,
#     'can_view_more_preview_comments': False,
#     'preview_comments': [],
#     'comment_count': 125,
#     'hide_view_all_comment_entrypoint': False,
#     'inline_composer_display_condition': 'impression_trigger',
#     'inline_composer_imp_trigger_time': 5,
#     'is_comments_gif_composer_enabled': True,
#     'comment_inform_treatment': {'action_type': None,
#      'should_have_inform_treatment': False,
#      'text': '',
#      'url': None},
#     'has_liked': False,
#     'like_count': 2718,
#     'facepile_top_likers': [],
#     'top_likers': [],
#     'clips_tab_pinned_user_ids': [],
#     'can_viewer_save': True,
#     'can_viewer_reshare': True,
#     'shop_routing_user_id': None,
#     'is_organic_product_tagging_eligible': False,
#     'igbio_product': None,
#     'featured_products': [],
#     'product_suggestions': [],
#     'is_reuse_allowed': True,
#     'has_more_comments': True,
#     'max_num_visible_preview_comments': 2,
#     'explore_hide_comments': False,
#     'is_open_to_public_submission': False},
#    {'taken_at': 1725928475,
#     'pk': '3453660828630795370',
#     'id': '3453660828630795370_482001976',
#     'fbid': '18025254281111940',
#     'device_timestamp': 1725927989501229,
#     'caption_is_edited': False,
#     'strong_id__': '3453660828630795370_482001976',
#     'deleted_reason': 0,
#     'has_shared_to_fb': 0,
#     'has_delayed_metadata': False,
#     'is_quiet_post': False,
#     'mezql_token': '',
#     'share_count_disabled': False,
#     'is_visual_reply_commenter_notice_enabled': True,
#     'like_and_view_counts_disabled': False,
#     'is_post_live_clips_media': False,
#     'comment_threading_enabled': True,
#     'is_unified_video': False,
#     'commerciality_status': 'not_commercial',
#     'client_cache_key': 'MzQ1MzY2MDgyODYzMDc5NTM3MA==.3',
#     'integrity_review_decision': 'pending',
#     'should_request_ads': False,
#     'is_reshare_of_text_post_app_media_in_ig': False,
#     'has_privately_liked': False,
#     'filter_type': 0,
#     'usertags': {'in': [{'categories': None,
#        'duration_in_video_in_sec': None,
#        'position': [0.5, 0.5],
#        'show_category_of_user': False,
#        'start_time_in_video_in_sec': None,
#        'user': {'pk': '3969072663',
#         'pk_id': '3969072663',
#         'id': '3969072663',
#         'full_name': 'Matheus Castro',
#         'is_private': False,
#         'strong_id__': '3969072663',
#         'username': 'matheus_mcastro',
#         'is_verified': False,
#         'profile_pic_id': '3451902283942016810_3969072663',
#         'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/458488527_1180672566570940_7570863953468056262_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=104&_nc_ohc=luXUof_uAs4Q7kNvgG_parJ&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYA9rKQmVXEF5ueEyRohHfzp9KC-DO6rYmQtRkay0TzUMQ&oe=66EBB7D6&_nc_sid=b41fef'}}]},
#     'photo_of_you': False,
#     'can_see_insights_as_brand': False,
#     'media_type': 1,
#     'code': 'C_t3jmxOERq',
#     'caption': {'bit_flags': 0,
#      'created_at': 1725928476,
#      'created_at_utc': 1725928476,
#      'did_report_as_spam': False,
#      'is_ranked_comment': False,
#      'pk': '18025254284111940',
#      'share_enabled': False,
#      'content_type': 'comment',
#      'media_id': '3453660828630795370',
#      'status': 'Active',
#      'type': 1,
#      'user_id': '482001976',
#      'strong_id__': '18025254284111940',
#      'has_translation': True,
#      'text': 'COMPRE NO SARANDI 🙌🏻\n.\nMeus cpx, entre tantas e tantas regiões atingidas em maio pelas chuvas, o Bairro Sarandi, na Zona Norte de Porto Alegre, foi um dos mais castigados. \nEntre tantas frentes necessárias de lá pra cá, uma delas está, sem dúvida, no fato de reconstruir aos poucos o ecossistema econômico do pequeno empreendedor nas mais diversas esferas de ofertas de serviços. Para isso, estamos promovendo publicidades e propagandas das lojas e o comércio em geral de forma gratuita para ajudar na visibilidade dos trabalhadores do bairro. \nE ESSE TRABALHO VAI LONGE… E TAMO JUNTO SEMPRE.\n.\nSE TU TEM COMÉRCIO NO SARANDI, ENTRA EM CONTATO COM A GENTE E VAMO AGENDAR UMA PUBLI AÍ NO TEU TRAMPO ✊🏻✊🏻\nChama aqui: (51) 99576-1087 (Matheus Castro)\nE se puder, COMPRE NO SARANDI ❤️\n.\n(Obs: aqui na minha bio existe um destaque de todas as lojas e serviços que a gente já divulgou até agora. Dá uma olhadinha ali 🤓)',
#      'user': {'pk': '482001976',
#       'pk_id': '482001976',
#       'id': '482001976',
#       'full_name': 'Marcito Castro',
#       'is_private': False,
#       'is_unpublished': False,
#       'strong_id__': '482001976',
#       'fbid_v2': '17841400539287531',
#       'username': 'marcitocastro',
#       'is_verified': True,
#       'profile_pic_id': '3436382941194761236_482001976',
#       'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef'},
#      'is_covered': False,
#      'private_reply_status': 0},
#     'fundraiser_tag': {'has_standalone_fundraiser': False},
#     'sharing_friction_info': {'bloks_app_url': None,
#      'should_have_sharing_friction': False,
#      'sharing_friction_payload': None},
#     'timeline_pinned_user_ids': [482001976],
#     'accessibility_caption': 'Photo by Marcito Castro in Sarandi, Porto Alegre with @matheus_mcastro. May be pop art of flag, poster, pie and text.',
#     'original_media_has_visual_reply_media': False,
#     'fb_user_tags': {'in': []},
#     'coauthor_producers': [{'pk': '3969072663',
#       'pk_id': '3969072663',
#       'id': '3969072663',
#       'full_name': 'Matheus Castro',
#       'is_private': False,
#       'strong_id__': '3969072663',
#       'username': 'matheus_mcastro',
#       'is_verified': False,
#       'profile_pic_id': '3451902283942016810_3969072663',
#       'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/458488527_1180672566570940_7570863953468056262_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=104&_nc_ohc=luXUof_uAs4Q7kNvgG_parJ&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYA9rKQmVXEF5ueEyRohHfzp9KC-DO6rYmQtRkay0TzUMQ&oe=66EBB7D6&_nc_sid=b41fef'}],
#     'coauthor_producer_can_see_organic_insights': False,
#     'invited_coauthor_producers': [],
#     'mashup_info': {'mashups_allowed': True,
#      'is_reuse_allowed': True,
#      'can_toggle_mashups_allowed': False,
#      'has_been_mashed_up': False,
#      'is_light_weight_check': True,
#      'is_light_weight_reuse_allowed_check': False,
#      'formatted_mashups_count': None,
#      'original_media': None,
#      'privacy_filtered_mashups_media_count': None,
#      'non_privacy_filtered_mashups_media_count': None,
#      'mashup_type': None,
#      'is_creator_requesting_mashup': False,
#      'has_nonmimicable_additional_audio': False,
#      'is_pivot_page_available': False},
#     'is_in_profile_grid': False,
#     'profile_grid_control_enabled': False,
#     'user': {'fbid_v2': '17841400539287531',
#      'feed_post_reshare_disabled': False,
#      'full_name': 'Marcito Castro',
#      'id': '482001976',
#      'is_private': False,
#      'is_unpublished': False,
#      'pk': '482001976',
#      'pk_id': '482001976',
#      'show_account_transparency_details': True,
#      'strong_id__': '482001976',
#      'third_party_downloads_enabled': 1,
#      'account_type': 3,
#      'account_badges': [],
#      'fan_club_info': {'autosave_to_exclusive_highlight': None,
#       'connected_member_count': None,
#       'fan_club_id': None,
#       'fan_club_name': None,
#       'has_enough_subscribers_for_ssc': None,
#       'is_fan_club_gifting_eligible': None,
#       'is_fan_club_referral_eligible': None,
#       'subscriber_count': None,
#       'fan_consideration_page_revamp_eligiblity': None},
#      'friendship_status': {'following': False,
#       'is_bestie': False,
#       'is_feed_favorite': False,
#       'is_restricted': False},
#      'has_anonymous_profile_picture': False,
#      'is_favorite': False,
#      'is_verified': True,
#      'profile_pic_id': '3436382941194761236_482001976',
#      'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef',
#      'transparency_product_enabled': False,
#      'username': 'marcitocastro',
#      'can_see_quiet_post_attribution': True},
#     'owner': {'fbid_v2': '17841400539287531',
#      'feed_post_reshare_disabled': False,
#      'full_name': 'Marcito Castro',
#      'id': '482001976',
#      'is_private': False,
#      'is_unpublished': False,
#      'pk': '482001976',
#      'pk_id': '482001976',
#      'show_account_transparency_details': True,
#      'strong_id__': '482001976',
#      'third_party_downloads_enabled': 1,
#      'account_type': 3,
#      'account_badges': [],
#      'fan_club_info': {'autosave_to_exclusive_highlight': None,
#       'connected_member_count': None,
#       'fan_club_id': None,
#       'fan_club_name': None,
#       'has_enough_subscribers_for_ssc': None,
#       'is_fan_club_gifting_eligible': None,
#       'is_fan_club_referral_eligible': None,
#       'subscriber_count': None,
#       'fan_consideration_page_revamp_eligiblity': None},
#      'friendship_status': {'following': False,
#       'is_bestie': False,
#       'is_feed_favorite': False,
#       'is_restricted': False},
#      'has_anonymous_profile_picture': False,
#      'is_favorite': False,
#      'is_verified': True,
#      'profile_pic_id': '3436382941194761236_482001976',
#      'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef',
#      'transparency_product_enabled': False,
#      'username': 'marcitocastro',
#      'can_see_quiet_post_attribution': True},
#     'image_versions2': {'candidates': [{'width': 1080,
#        'height': 1080,
#        'url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/459083354_473311215704110_9173933237595551627_n.jpg?stp=dst-jpg_e35_s1080x1080&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE0NDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=110&_nc_ohc=iQBiCqralZsQ7kNvgF9q39p&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzQ1MzY2MDgyODYzMDc5NTM3MA%3D%3D.3-ccb7-5&oh=00_AYAIJHhBB_LhqWY2gOnbcDrGEes7c6zxesOHtBbvNG4A0w&oe=66EB9541&_nc_sid=b41fef',
#        'scans_profile': 'e35'},
#       {'width': 360,
#        'height': 360,
#        'url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.29350-15/459083354_473311215704110_9173933237595551627_n.jpg?stp=dst-jpg_e35_s360x360&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xNDQweDE0NDAuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=110&_nc_ohc=iQBiCqralZsQ7kNvgF9q39p&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzQ1MzY2MDgyODYzMDc5NTM3MA%3D%3D.3-ccb7-5&oh=00_AYBaNgrYpN23Y5AXgbvC1Qz9ClKz2IRhgKth8_P3y7qQyw&oe=66EB9541&_nc_sid=b41fef',
#        'scans_profile': 'e35'}]},
#     'original_width': 1440,
#     'original_height': 1440,
#     'media_notes': {'items': []},
#     'enable_media_notes_production': False,
#     'product_type': 'feed',
#     'is_paid_partnership': False,
#     'location': {'address': '',
#      'city': 'Sarandi, Porto Alegre',
#      'external_source': 'facebook_places',
#      'facebook_places_id': '387286275043728',
#      'has_viewer_saved': False,
#      'is_eligible_for_guides': True,
#      'lat': -29.9826508,
#      'lng': -51.1357445,
#      'name': 'Sarandi, Porto Alegre',
#      'pk': '387286275043728',
#      'short_name': 'Sarandi'},
#     'music_metadata': {'audio_type': 'licensed_music',
#      'music_canonical_id': '18147549274067643',
#      'pinned_media_ids': [],
#      'music_info': {'music_canonical_id': None,
#       'music_asset_info': {'allows_saving': True,
#        'artist_id': '448384941220109',
#        'audio_asset_id': '2182774348439132',
#        'audio_cluster_id': '2093438510738675',
#        'cover_artwork_thumbnail_uri': 'https://scontent-iad3-2.xx.fbcdn.net/v/t39.30808-6/427927660_1783257318815600_7043716200694357466_n.jpg?stp=dst-jpg_s168x128&_nc_cat=109&ccb=1-7&_nc_sid=2f2557&_nc_ohc=Tb-l0Dq8vd4Q7kNvgFlH80q&_nc_ad=z-m&_nc_cid=0&_nc_ht=scontent-iad3-2.xx&_nc_gid=A7mXzWhabDQU8PbHYIz_LSJ&oh=00_AYC52GpQR3eJbbRdF6f7E7BGnAQItgqm3Oe8BAUc_w4Hjw&oe=66EBA5C1',
#        'cover_artwork_uri': 'https://scontent-iad3-2.xx.fbcdn.net/v/t39.30808-6/427927660_1783257318815600_7043716200694357466_n.jpg?stp=dst-jpg_s168x128&_nc_cat=109&ccb=1-7&_nc_sid=2f2557&_nc_ohc=Tb-l0Dq8vd4Q7kNvgFlH80q&_nc_ad=z-m&_nc_cid=0&_nc_ht=scontent-iad3-2.xx&_nc_gid=A7mXzWhabDQU8PbHYIz_LSJ&oh=00_AYC52GpQR3eJbbRdF6f7E7BGnAQItgqm3Oe8BAUc_w4Hjw&oe=66EBA5C1',
#        'dark_message': None,
# ...
#     'is_artist_pick': False,
#     'media_notes': {'items': []},
#     'enable_media_notes_production': False,
#     'product_type': 'clips',
#     'is_paid_partnership': False,
#     'music_metadata': None,
#     'social_context': [],
#     'organic_tracking_token': '',
#     'is_third_party_downloads_eligible': True,
#     'ig_media_sharing_disabled': False,
#     'are_remixes_crosspostable': True,
#     'boost_unavailable_identifier': None,
#     'boost_unavailable_reason': None,
#     'boost_unavailable_reason_v2': [],
#     'subscribe_cta_visible': False,
#     'is_cutout_sticker_allowed': False,
#     'gen_ai_detection_method': {'detection_method': 'NONE'},
#     'fb_aggregated_like_count': 0,
#     'fb_aggregated_comment_count': 0,
#     'has_high_risk_gen_ai_inform_treatment': False,
#     'open_carousel_show_follow_button': False,
#     'is_tagged_media_shared_to_viewer_profile_grid': False,
#     'should_show_author_pog_for_tagged_media_shared_to_profile_grid': False,
#     'is_eligible_for_media_note_recs_nux': False,
#     'is_social_ufi_disabled': False,
#     'is_eligible_for_meta_ai_share': False,
#     'fb_like_count': 1997,
#     'can_reply': False,
#     'can_view_more_preview_comments': False,
#     'preview_comments': [],
#     'comment_count': 767,
#     'hide_view_all_comment_entrypoint': False,
#     'inline_composer_display_condition': 'impression_trigger',
#     'inline_composer_imp_trigger_time': 5,
#     'is_comments_gif_composer_enabled': True,
#     'comment_inform_treatment': {'action_type': None,
#      'should_have_inform_treatment': False,
#      'text': '',
#      'url': None},
#     'has_liked': False,
#     'like_count': 46032,
#     'facepile_top_likers': [],
#     'top_likers': [],
#     'video_subtitles_locale': 'pt_BR',
#     'is_dash_eligible': 1,
#     'video_dash_manifest': '<?xml version="1.0" encoding="UTF-8"?>\n<MPD xmlns="urn:mpeg:dash:schema:mpd:2011" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="urn:mpeg:dash:schema:mpd:2011 DASH-MPD.xsd" profiles="urn:mpeg:dash:profile:isoff-on-demand:2011" minBufferTime="PT2S" type="static" mediaPresentationDuration="PT49.039093S"><Period id="0" duration="PT49.039093S"><AdaptationSet id="0" contentType="video" frameRate="15360/512" subsegmentAlignment="true" par="9:16" FBUnifiedUploadResolutionMos="360:67"><SupplementalProperty schemeIdUri="urn:mpeg:mpegB:cicp:TransferCharacteristics" value="1"/><Representation id="1494918551388816vd" bandwidth="651108" codecs="avc1.64001f" mimeType="video/mp4" sar="1:1" FBEncodingTag="dash_baseline_1_v1" FBContentLength="3988038" FBPlaybackResolutionMos="0:100,360:88.2,480:85.4" FBPlaybackResolutionMosConfidenceLevel="high" FBPlaybackResolutionCsvqm="0:100,360:95.9,480:95.1,720:95.1,1080:95.1" FBAbrPolicyTags="avoid_on_cellular,avoid_on_cellular_intentional" width="480" height="854" FBDefaultQuality="1" FBQualityClass="sd" FBQualityLabel="480p"><BaseURL>https://scontent-iad3-1.cdninstagram.com/o1/v/t16/f1/m86/DD43D7F5CD0D2667C522819D7ECEBA94_video_dashinit.mp4?efg=eyJ2aWRlb19pZCI6bnVsbCwidmVuY29kZV90YWciOiJpZy14cHZkcy5jbGlwcy5jMi1DMy5kYXNoX2Jhc2VsaW5lXzFfdjEifQ&amp;_nc_ht=scontent-iad3-1.cdninstagram.com&amp;_nc_cat=104&amp;ccb=9-4&amp;oh=00_AYCumpat8f9RlV7BRDV75h-i0plil58Y7UAvFHOaikOytw&amp;oe=66E7B72A&amp;_nc_sid=9ca052</BaseURL><SegmentBase indexRange="891-1042" timescale="15360" FBMinimumPrefetchRange="1043-45662" FBFirstSegmentRange="1043-335677" FBFirstSegmentDuration="5000" FBSecondSegmentRange="335678-738320" FBPrefetchSegmentRange="1043-335677" FBPrefetchSegmentDuration="5000"><Initialization range="0-890"/></SegmentBase></Representation><Representation id="995964205614732v" bandwidth="279337" codecs="avc1.4d001e" mimeType="video/mp4" sar="1:1" FBEncodingTag="dash_baseline_3_v1" FBContentLength="1710943" FBPlaybackResolutionMos="0:100,360:68.7,480:65.3" FBPlaybackResolutionMosConfidenceLevel="high" FBPlaybackResolutionCsvqm="0:100,360
video_dashinit.mp4?efg=eyJ2ZW5jb2RlX3RhZyI6Inhwdl9wcm9ncmVzc2l2ZS5JTlNUQUdSQU0uQ0xJUFMuQzMuMzYwLmRhc2hfYmFzZWxpbmVfM192MSJ9&_nc_ht=scontent-atl3-1.cdninstagram.com&_nc_cat=100&vs=8c2e5bc5069546cd&_nc_vs=_gcA&ccb=9-4&oh=00_AYCLDPyuAszWcxk71CEwnKmeHlGcd9j4BAxoFPomd3RLGg&oe=66E7B83E&_nc_sid=1d576d',
#       'width': 360}],
#     'video_duration': 49.016,
#     'has_audio': True,
#     'clips_tab_pinned_user_ids': [],
#     'clips_metadata': {'breaking_content_info': None,
#      'breaking_creator_info': None,
#      'clips_creation_entry_point': 'clips',
#      'featured_label': None,
#      'is_public_chat_welcome_video': False,
#      'is_shared_to_fb': True,
#      'professional_clips_upsell_type': 0,
#      'reels_on_the_rise_info': None,
#      'show_tips': None,
#      'achievements_info': {'num_earned_achievements': None,
#       'show_achievements': False},
#      'additional_audio_info': {'additional_audio_username': None,
#       'audio_reattribution_info': {'should_allow_restore': False}},
#      'asset_recommendation_info': None,
#      'audio_ranking_info': {'best_audio_cluster_id': '2272576929574693'},
#      'audio_type': 'original_sounds',
#      'branded_content_tag_info': {'can_add_tag': False},
#      'challenge_info': None,
#      'content_appreciation_info': {'enabled': True,
#       'entry_point_container': {'pill': {'action_type': 'gifting',
#         'priority': 3},
#        'comment': {'action_type': 'gifting'},
#        'overflow': None,
#        'ufi': None}},
#      'contextual_highlight_info': None,
#      'cutout_sticker_info': [],
#      'disable_use_in_clips_client_cache': False,
#      'external_media_info': None,
#      'is_fan_club_promo_video': False,
#      'mashup_info': {'mashups_allowed': True,
#       'is_reuse_allowed': True,
#       'can_toggle_mashups_allowed': False,
#       'has_been_mashed_up': True,
#       'is_light_weight_check': True,
#       'is_light_weight_reuse_allowed_check': False,
#       'formatted_mashups_count': None,
#       'original_media': None,
#       'privacy_filtered_mashups_media_count': None,
#       'non_privacy_filtered_mashups_media_count': 12,
#       'mashup_type': None,
#       'is_creator_requesting_mashup': False,
#       'has_nonmimicable_additional_audio': False,
#       'is_pivot_page_available': True},
#      'merchandising_pill_info': None,
#      'music_canonical_id': '18354898957119795',
#      'music_info': None,
#      'nux_info': None,
#      'original_sound_info': {'allow_creator_to_rename': True,
#       'audio_asset_id': '557135429979272',
#       'can_remix_be_shared_to_fb': True,
#       'can_remix_be_shared_to_fb_expansion': False,
#       'dash_manifest': '<?xml version="1.0" encoding="UTF-8"?>\n<!--Generated with https://github.com/google/shaka-packager version v2.5.1-release-->\n<MPD xmlns="urn:mpeg:dash:schema:mpd:2011" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="urn:mpeg:dash:schema:mpd:2011 DASH-MPD.xsd" profiles="urn:mpeg:dash:profile:isoff-on-demand:2011" minBufferTime="PT2S" type="static" mediaPresentationDuration="PT49.039093017578125S">\n  <Period id="0">\n    <AdaptationSet id="0" contentType="audio" subsegmentAlignment="true">\n      <Representation id="0" bandwidth="81863" codecs="mp4a.40.5" mimeType="audio/mp4" audioSamplingRate="44100">\n        <AudioChannelConfiguration schemeIdUri="urn:mpeg:dash:23003:3:audio_channel_configuration:2011" value="2"/>\n        <BaseURL>https://scontent-iad3-1.cdninstagram.com/v/t39.12897-6/458330821_556400753382216_4152796991355615733_n.m4a?_nc_cat=108&amp;ccb=1-7&amp;_nc_sid=c2de2f&amp;_nc_ohc=NkoqjDogba0Q7kNvgFYoXzE&amp;_nc_ad=z-m&amp;_nc_cid=0&amp;_nc_ht=scontent-iad3-1.cdninstagram.com&amp;_nc_gid=AuIsEH7J2Qi0_S0-CqeVvkK&amp;oh=00_AYApq6XoKnmImiE4waGQWm4oc4RYHMNJSpxkhcM1CHn04Q&amp;oe=66EBA472</BaseURL>\n        <SegmentBase indexRange="817-1148" timescale="44100">\n          <Initialization range="0-816"/>\n        </SegmentBase>\n      </Representation>\n    </AdaptationSet>\n  </Period>\n</MPD>\n',
#       'duration_in_ms': 49039,
#       'formatted_clips_media_count': None,
#       'hide_remixing': False,
#       'ig_artist': {'pk': '482001976',
#        'pk_id': '482001976',
#        'id': '482001976',
#        'full_name': 'Marcito Castro',
#        'is_private': False,
#        'strong_id__': '482001976',
#        'username': 'marcitocastro',
#        'is_verified': True,
#        'profile_pic_id': '3436382941194761236_482001976',
#        'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef'},
#       'is_audio_automatically_attributed': False,
#       'is_eligible_for_audio_effects': True,
#       'is_eligible_for_vinyl_sticker': None,
#       'is_explicit': False,
#       'is_original_audio_download_eligible': True,
#       'is_reuse_disabled': False,
#       'is_xpost_from_fb': False,
#       'music_canonical_id': None,
#       'oa_owner_is_music_artist': False,
#       'original_audio_subtype': 'default',
#       'original_audio_title': 'Original audio',
#       'original_media_id': '3451922605865020453',
#       'progressive_download_url': 'https://scontent-iad3-1.cdninstagram.com/v/t39.12897-6/458407957_769468535190965_352390270014400415_n.m4a?_nc_cat=101&ccb=1-7&_nc_sid=c2de2f&_nc_ohc=FZoHLylALdMQ7kNvgHGsWZZ&_nc_ad=z-m&_nc_cid=0&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_gid=AuIsEH7J2Qi0_S0-CqeVvkK&oh=00_AYDVI6ImfHEbrfdklNABLYrsUd_1YHzE4tQAxN3OqfE3Dg&oe=66EBB765',
#       'should_mute_audio': False,
#       'time_created': 1725721411,
#       'trend_rank': None,
#       'previous_trend_rank': None,
#       'overlap_duration_in_ms': None,
#       'audio_asset_start_time_in_ms': None,
#       'audio_filter_infos': [],
#       'audio_parts': [],
#       'audio_parts_by_filter': [],
#       'consumption_info': {'display_media_id': None,
#        'is_bookmarked': False,
#        'is_trending_in_clips': False,
#        'should_mute_audio_reason': '',
#        'should_mute_audio_reason_type': None},
#       'xpost_fb_creator_info': None},
#      'originality_info': None,
#      'reusable_text_attribute_string': None,
#      'reusable_text_info': None,
#      'shopping_info': None,
#      'show_achievements': False,
#      'template_info': None,
#      'viewer_interaction_settings': None},
#     'can_viewer_save': True,
#     'can_viewer_reshare': True,
#     'reshare_count': 26287,
#     'shop_routing_user_id': None,
#     'is_organic_product_tagging_eligible': False,
#     'igbio_product': None,
#     'featured_products': [],
#     'product_suggestions': [],
#     'is_reuse_allowed': True,
#     'has_more_comments': True,
#     'max_num_visible_preview_comments': 2,
#     'explore_hide_comments': False,
#     'is_open_to_public_submission': False}],
#   'next_max_id': '3451922605865020453_482001976',
#   'user': {'pk': '482001976',
#    'pk_id': '482001976',
#    'full_name': 'Marcito Castro',
#    'is_private': False,
#    'strong_id__': '482001976',
#    'profile_grid_display_type': 'default',
#    'id': '482001976',
#    'username': 'marcitocastro',
#    'is_verified': True,
#    'profile_pic_id': '3436382941194761236_482001976',
#    'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef'},
#   'auto_load_more_enabled': True},
#  'status': 'ok',
#  'message': None}

# %%
# Obtém o ID máximo para a proxima página.
next_max_id = response_instagram.get('data').get('next_max_id')

# Obtém a lista de postagens do perfil
items = response_instagram.get('data').get('items')

codigo_ultima_postagem = ''

# Lista para armazenar os dados das postagens
data_posts = []

data = response_instagram.get('data')


# Itera sobre cada postagem na lista de postagens
for post in items:
  id = post.get('id') # ID da postagem
  code = post.get('code') # Código da postagem

  # print(f'A postagem é fixada? {post.get("timeline_pinned_user_ids")==None}')
  if post.get('timeline_pinned_user_ids') == None:
    if codigo_ultima_postagem == '':
      codigo_ultima_postagem = code

  device_timestamp = post.get('device_timestamp') # Lembrar de converter
  like_and_view_counts_disabled = post.get('like_and_view_counts_disabled') #?

  usertags = post.get('usertags',{}) #@ marcados

  list_marcados = []

  for marcados in usertags.get('in',[]):
    list_marcados.append({f"username" :marcados.get('user').get('username'),"full_name" :marcados.get('user').get('full_name')})

  caption = post.get('caption')
  image_versions2 = post.get('image_versions2')
  product_type = post.get('product_type')
  coauthor_producers = post.get('coauthor_producers')
  like_count = post.get('like_count')
  comment_count = post.get('comment_count')
  reshare_count = post.get('reshare_count') #encaminhamentos
  timeline_pinned_user_ids = post.get('timeline_pinned_user_ids')


  # print(f'id: {id}')
  # print(f'code: {code}')
  # print(f'device_timestamp: {device_timestamp}')
  # print(f'like_and_view_counts_disabled: {like_and_view_counts_disabled}')
  # print(f'list_marcados: {list_marcados}')
  # print(f'caption: {caption}')
  # print(f'image_versions2: {image_versions2}')
  # print(f'product_type: {product_type}')
  # print(f'coauthor_producers: {coauthor_producers}')
  # print(f'like_count: {like_count}')
  # print(f'comment_count: {comment_count}')
  # print(f'reshare_count: {reshare_count}')
  # print(f'timeline_pinned_user_ids: {timeline_pinned_user_ids}')

  # print('-----------------------------')



  schema = StructType([
    StructField("id", StringType(), nullable=True),
    StructField("code", StringType(), nullable=True),
    StructField("device_timestamp", StringType(), nullable=True),
    StructField("like_and_view_counts_disabled", StringType(), nullable=True),
    # StructField("list_marcados", ArrayType(), nullable=True),
    StructField("caption", StringType(), nullable=True),
    StructField("image_versions2", StringType(), nullable=True),
    StructField("product_type", StringType(), nullable=True),
    StructField("coauthor_producers", StringType(), nullable=True),
    StructField("like_count", StringType(), nullable=True),
    StructField("comment_count", StringType(), nullable=True),
    StructField("reshare_count", StringType(), nullable=True),
    StructField("timeline_pinned_user_ids", StringType(), nullable=True)
    ])

  data_posts.append((id,code,device_timestamp,like_and_view_counts_disabled,caption,image_versions2,product_type,coauthor_producers,like_count,comment_count,reshare_count,timeline_pinned_user_ids))
  # data_posts.append((id,code))

print(data_posts)

df = spark.createDataFrame(data_posts, schema=schema)

# # Criando o DataFrame
# df = spark.createDataFrame(data, columns)

df = df.withColumn('ts_exec', F.current_timestamp())

# # Mostrando o DataFrame
df.write.mode("append").format('parquet').save('/content/Datalake/Instagram/Postagens_v2/')

df.show(truncate=False)
# Out:
# [('3448401954307684253_482001976', 'C_bL06ZRbed', 172530125116770, False, {'bit_flags': 0, 'created_at': 1725301569, 'created_at_utc': 1725301569, 'did_report_as_spam': False, 'is_ranked_comment': False, 'pk': '18433122463066480', 'share_enabled': False, 'content_type': 'comment', 'media_id': '3448401954307684253', 'status': 'Active', 'type': 1, 'user_id': '482001976', 'strong_id__': '18433122463066480', 'has_translation': True, 'text': 'TESTANDO PIADAS - 4ª edição 💃🏻\n.\nAs três primeiras edições do “Testando Piadas” na Amrigs foram um sucesso. E vamo de novo.\nPra quem não tá ligado, sempre no último domingo de cada mês eu tô lá testando piadas novos e trazendo comigo uns cpx pra também testar as deles.\nDessa vez, 29 DE SETEMBRO (19h), vou estar com a @ursamalgarizi e o @sortiagao no elenco.\nE de quebra tem uma canja do Diego Capela, o @guridafarmacia \n.\nVAI DÁ BOM DE NOVO, então garante teu ingresso e vamo colar junto lá com a gente \U0001faf6🏻🥳\n.\nINGRESSOS nos STORIES e na BIO 🚀', 'user': {'pk': '482001976', 'pk_id': '482001976', 'id': '482001976', 'full_name': 'Marcito Castro', 'is_private': False, 'is_unpublished': False, 'strong_id__': '482001976', 'fbid_v2': '17841400539287531', 'username': 'marcitocastro', 'is_verified': True, 'profile_pic_id': '3436382941194761236_482001976', 'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef'}, 'is_covered': False, 'private_reply_status': 0}, {'candidates': [{'width': 1080, 'height': 1346, 'url': 'https://scontent-iad3-2.cdninstagram.com/v/t51.29350-15/457666545_1031201388485124_4865510190400477601_n.jpg?stp=dst-jpg_e35_p1080x1080&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ3eDE2Nzkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=100&_nc_ohc=9WLgpWPU3HUQ7kNvgEYKhrV&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzQ0ODQwMTk1NDMwNzY4NDI1Mw%3D%3D.3-ccb7-5&oh=00_AYCqVOcQTMMVBcbKXDIPewfAFE_Q6LaTAPsACftlhh-Law&oe=66EBB9DF&_nc_sid=b41fef', 'scans_profile': 'e35'}, {'width': 360, 'height': 449, 'url': 'https://scontent-iad3-2.cdninstagram.com/v/t51.29350-15/457666545_1031201388485124_4865510190400477601_n.jpg?stp=dst-jpg_e35_p360x360&efg=eyJ2ZW5jb2RlX3RhZyI6ImltYWdlX3VybGdlbi4xMzQ3eDE2Nzkuc2RyLmYyOTM1MC5kZWZhdWx0X2ltYWdlIn0&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=100&_nc_ohc=9WLgpWPU3HUQ7kNvgEYKhrV&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&ig_cache_key=MzQ0ODQwMTk1NDMwNzY4NDI1Mw%3D%3D.3-ccb7-5&oh=00_AYB4NpS4p4Xt_i-Q5FKFovGtQFmjlU9-D3Ebf1n21k-6pg&oe=66EBB9DF&_nc_sid=b41fef', 'scans_profile': 'e35'}]}, 'feed', [], 567, 21, None, [482001976]), ('3444865860697304235_482001976', 'C_Onz-lu6yr', 1724879928670751, False, {'bit_flags': 0, 'created_at': 1724880034, 'created_at_utc': 1724880034, 'did_report_as_spam': False, 'is_ranked_comment': False, 'pk': '18036550175482371', 'share_enabled': False, 'content_type': 'comment', 'media_id': '3444865860697304235', 'status': 'Active', 'type': 1, 'user_id': '482001976', 'strong_id__': '18036550175482371', 'has_translation': True, 'text': 'AGENDINHA REGIONAL RAIZ DE SETEMBRO ❤️❤️🌹\n.\nIngresso nos stories e na bio 🚀', 'user': {'pk': '482001976', 'pk_id': '482001976', 'id': '482001976', 'full_name': 'Marcito Castro', 'is_private': False, 'is_unpublished': False, 'strong_id__': '482001976', 'fbid_v2': '17841400539287531', 'username': 'marcitocastro', 'is_verified': True, 'profile_pic_id': '3436382941194761236_482001976', 'profile_pic_url': 'https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b ...
# +-----------------------------+-----------+----------------+-----------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |id                           |code       |device_timestamp|like_and_view_counts_disabled|caption                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |image_versions2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# +-----------------------------+-----------+----------------+-----------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |3448401954307684253_482001976|C_bL06ZRbed|172530125116770 |false                        |{private_reply_status=0, share_enabled=false, created_at=1725301569, type=1, is_covered=false, created_at_utc=1725301569, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=
has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3448401954307684253, text=TESTANDO PIADAS - 4ª edição 💃🏻
# .
# As três primeiras edições do “Testando Piadas” na Amrigs foram um sucesso. E vamo de novo.
# Pra quem não tá ligado, sempre no último domingo de cada mês eu tô lá testando piadas novos e trazendo comigo uns cpx pra também testar as deles.
# Dessa vez, 29 DE SETEMBRO (19h), vou estar com a @ursamalgarizi e o @sortiagao no elenco.
# E de quebra tem uma canja do Diego Capela, o @guridafarmacia
# .
# VAI DÁ BOM DE NOVO, então garante teu ingresso e vamo colar junto lá com a gente 🫶🏻🥳
# .
# INGRESSOS nos STORIES e na BIO 🚀, pk=18433122463066480, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18433122463066480, status=Active}                                                                                                                                                                                                                                                                                                                                                                                |567       |21           |
# |{private_reply_status=0, share_enabled=false, created_at=1724880034, type=1, is_covered=false, created_at_utc=1724880034, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3444865860697304235, text=AGENDINHA REGIONAL RAIZ DE SETEMBRO ❤️❤️🌹
# .
# Ingresso nos stories e na bio 🚀, pk=18036550175482371, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18036550175482371, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |2718      |125          |
# |{private_reply_status=0, share_enabled=false, created_at=1725928476, type=1, is_covered=false, created_at_utc=1725928476, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3453660828630795370, text=COMPRE NO SARANDI 🙌🏻
# .
# Meus cpx, entre tantas e tantas regiões atingidas em maio pelas chuvas, o Bairro Sarandi, na Zona Norte de Porto Alegre, foi um dos mais castigados.
# Entre tantas frentes necessárias de lá pra cá, uma delas está, sem dúvida, no fato de reconstruir aos poucos o ecossistema econômico do pequeno empreendedor nas mais diversas esferas de ofertas de serviços. Para isso, estamos promovendo publicidades e propagandas das lojas e o comércio em geral de forma gratuita para ajudar na visibilidade dos trabalhadores do bairro.
# E ESSE TRABALHO VAI LONGE… E TAMO JUNTO SEMPRE.
# .
# SE TU TEM COMÉRCIO NO SARANDI, ENTRA EM CONTATO COM A GENTE E VAMO AGENDAR UMA PUBLI AÍ NO TEU TRAMPO ✊🏻✊🏻
# Chama aqui: (51) 99576-1087 (Matheus Castro)
# E se puder, COMPRE NO SARANDI ❤️
# .
# (Obs: aqui na minha bio existe um destaque de todas as lojas e serviços que a gente já divulgou até agora. Dá uma olhadinha ali 🤓), pk=18025254284111940, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18025254284111940, status=Active}|1145      |25           |
# |{private_reply_status=0, share_enabled=false, created_at=1726274370, type=1, is_covered=false, created_at_utc=1726274370, content_type=comment, user_id=482001976, bit_flags=0, media_id=3456562400289500326, text=QUE LINDEZA MEUS CPX DE GUAÍBA 😍🫶🏻🥹👏🏻, pk=18043829857970353, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18043829857970353, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |1179      |43           |
# |{private_reply_status=0, share_enabled=false, created_at=1726265713, type=1, is_covered=false, created_at_utc=1726265713, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3456489139740503024, text=VEM NOVIDADE AÍ 🫢🔥
# ❗️❗️❗️🔞🔞❗️❗️❗️
# .
# .
# .
# #privacy #onlyfans #marcito #piada #comedian #humor #standupcomedy #fy #fyp, pk=18037028501146248, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18037028501146248, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |10289     |176          |
# |{private_reply_status=0, share_enabled=false, created_at=1726250265, type=1, is_covered=false, created_at_utc=1726250265, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3456360192750933699, text=ONTEM FOI NOITE DE STAND UP NO CINEMA NO PROJETO QUINTA COMEDY COM A REALIZAÇÃO DA @artistaria NO @arcoplexcinemas NO @shoppingdovalers EM CACHOEIRINHA
# Lotamos a casa e outubro e novembro tamo lá de novo 😍🫶🏻, pk=18121686001353732, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18121686001353732, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |358       |14           |
# |{private_reply_status=0, share_enabled=false, created_at=1725301569, type=1, is_covered=false, created_at_utc=1725301569, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3448401954307684253, text=TESTANDO PIADAS - 4ª edição 💃🏻
# .
# As três primeiras edições do “Testando Piadas” na Amrigs foram um sucesso. E vamo de novo.
# Pra quem não tá ligado, sempre no último domingo de cada mês eu tô lá testando piadas novos e trazendo comigo uns cpx pra também testar as deles.
# Dessa vez, 29 DE SETEMBRO (19h), vou estar com a @ursamalgarizi e o @sortiagao no elenco.
# E de quebra tem uma canja do Diego Capela, o @guridafarmacia
# .
# VAI DÁ BOM DE NOVO, então garante teu ingresso e vamo colar junto lá com a gente 🫶🏻🥳
# .
# INGRESSOS nos STORIES e na BIO 🚀, pk=18433122463066480, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgFc_56E&_nc_gid=aedff0ffa1f74a71a2dfbb7becc84fc9&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAjsDOf2MpMtQBWQl6bq4dueRisLu1VLN-xvtClhAR3hA&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18433122463066480, status=Active}                                                                                                                                                                                                                                                                                                                                                                                |567       |21           |
# |{private_reply_status=0, share_enabled=false, created_at=1724880034, type=1, is_covered=false, created_at_utc=1724880034, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3444865860697304235, text=AGENDINHA REGIONAL RAIZ DE SETEMBRO ❤️❤️🌹
# .
# Ingresso nos stories e na bio 🚀, pk=18036550175482371, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgFc_56E&_nc_gid=aedff0ffa1f74a71a2dfbb7becc84fc9&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAjsDOf2MpMtQBWQl6bq4dueRisLu1VLN-xvtClhAR3hA&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18036550175482371, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |2718      |125          |
# |{private_reply_status=0, share_enabled=false, created_at=1725928476, type=1, is_covered=false, created_at_utc=1725928476, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3453660828630795370, text=COMPRE NO SARANDI 🙌🏻
# .
# Meus cpx, entre tantas e tantas regiões atingidas em maio pelas chuvas, o Bairro Sarandi, na Zona Norte de Porto Alegre, foi um dos mais castigados.
# Entre tantas frentes necessárias de lá pra cá, uma delas está, sem dúvida, no fato de reconstruir aos poucos o ecossistema econômico do pequeno empreendedor nas mais diversas esferas de ofertas de serviços. Para isso, estamos promovendo publicidades e propagandas das lojas e o comércio em geral de forma gratuita para ajudar na visibilidade dos trabalhadores do bairro.
# E ESSE TRABALHO VAI LONGE… E TAMO JUNTO SEMPRE.
# .
# SE TU TEM COMÉRCIO NO SARANDI, ENTRA EM CONTATO COM A GENTE E VAMO AGENDAR UMA PUBLI AÍ NO TEU TRAMPO ✊🏻✊🏻
# Chama aqui: (51) 99576-1087 (Matheus Castro)
# E se puder, COMPRE NO SARANDI ❤️
# .
# (Obs: aqui na minha bio existe um destaque de todas as lojas e serviços que a gente já divulgou até agora. Dá uma olhadinha ali 🤓), pk=18025254284111940, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgFc_56E&_nc_gid=aedff0ffa1f74a71a2dfbb7becc84fc9&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAjsDOf2MpMtQBWQl6bq4dueRisLu1VLN-xvtClhAR3hA&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18025254284111940, status=Active}|1145      |25           |
# |{private_reply_status=0, share_enabled=false, created_at=1726274370, type=1, is_covered=false, created_at_utc=1726274370, content_type=comment, user_id=482001976, bit_flags=0, media_id=3456562400289500326, text=QUE LINDEZA MEUS CPX DE GUAÍBA 😍🫶🏻🥹👏🏻, pk=18043829857970353, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgFc_56E&_nc_gid=aedff0ffa1f74a71a2dfbb7becc84fc9&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAjsDOf2MpMtQBWQl6bq4dueRisLu1VLN-xvtClhAR3hA&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18043829857970353, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |1178      |43           |
# |{private_reply_status=0, share_enabled=false, created_at=1726265713, type=1, is_covered=false, created_at_utc=1726265713, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3456489139740503024, text=VEM NOVIDADE AÍ 🫢🔥
# ❗️❗️❗️🔞🔞❗️❗️❗️
# .
# .
# .
# #privacy #onlyfans #marcito #piada #comedian #humor #standupcomedy #fy #fyp, pk=18037028501146248, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgFc_56E&_nc_gid=aedff0ffa1f74a71a2dfbb7becc84fc9&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAjsDOf2MpMtQBWQl6bq4dueRisLu1VLN-xvtClhAR3hA&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18037028501146248, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |10270     |176          |
# |{private_reply_status=0, share_enabled=false, created_at=1726250265, type=1, is_covered=false, created_at_utc=1726250265, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3456360192750933699, text=ONTEM FOI NOITE DE STAND UP NO CINEMA NO PROJETO QUINTA COMEDY COM A REALIZAÇÃO DA @artistaria NO @arcoplexcinemas NO @shoppingdovalers EM CACHOEIRINHA
# Lotamos a casa e outubro e novembro tamo lá de novo 😍🫶🏻, pk=18121686001353732, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgFc_56E&_nc_gid=aedff0ffa1f74a71a2dfbb7becc84fc9&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAjsDOf2MpMtQBWQl6bq4dueRisLu1VLN-xvtClhAR3hA&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18121686001353732, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |358       |14           |
# |{private_reply_status=0, share_enabled=false, created_at=1726197929, type=1, is_covered=false, created_at_utc=1726197929, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3455920342591633777, text=Valeu pelo carinho @seumauricio sou um grande fã do teu trabalho também ❤️✊🏻✊🏻, pk=18103130803431375, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18103130803431375, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |14355     |390          |
# |{private_reply_status=0, share_enabled=false, created_at=1726175796, type=1, is_covered=false, created_at_utc=1726175796, content_type=comment, user_id=482001976, bit_flags=0, media_id=3455734369313129565, text=#tbt & #tdah, pk=17939973362864228, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=17939973362864228, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |14894     |161          |
# |{private_reply_status=0, share_enabled=false, created_at=1725924250, type=1, is_covered=false, created_at_utc=1725924250, content_type=comment, user_id=482001976, bit_flags=0, media_id=3453624393492115241, text=Jaaaaaaime!
# .
# .
# .
# #repost #anos90 #nostalgia #propagandas #humor #comedia #standupcomedy #piada #marcito #fy, pk=17932176845806962, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=17932176845806962, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |31465     |598          |
# |{private_reply_status=0, share_enabled=false, created_at=1725830275, type=1, is_covered=false, created_at_utc=1725830275, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3452836177604369196, text=Um Gaúcho no exterior (Paraná, Brazil) 🥳🫶🏻
# .
# .
# .
# #repost #humor #gaucho #sotaque #dialeto #giria #rs #brazil #brasil #piada #comedia #standupcomedy #marcito #fy #fyp, pk=18019659656217969, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18019659656217969, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |34079     |255          |
# |{private_reply_status=0, share_enabled=false, created_at=1725812661, type=1, is_covered=false, created_at_utc=1725812661, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3452689303891159947, text=Dois filhos, uma nora e um senhor de idade 😐👴🏻, pk=18031208162033945, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18031208162033945, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |17861     |208          |
# |{private_reply_status=0, share_enabled=false, created_at=1725721408, type=1, is_covered=false, created_at_utc=1725721408, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3451922605865020453, text=O GAÚCHO EM SETEMBRO 😁
# .
# .
# .
# #humor #repost #piada #comedia #riograndedosul #brasil #7desetembro #feriado #standupcomedy #gaucho #marcito #fy #fyp, pk=18451163413011613, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgEhiS0J&_nc_gid=986a97683b2340ce914791238d6952c8&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAcQxzw4XOcgqfubxKFpG9hRnBsW5NApdmSrswA3IDcxg&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18451163413011613, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |46032     |767          |
# |{private_reply_status=0, share_enabled=false, created_at=1726197929, type=1, is_covered=false, created_at_utc=1726197929, has_translation=true, content_type=comment, user_id=482001976, bit_flags=0, media_id=3455920342591633777, text=Valeu pelo carinho @seumauricio sou um grande fã do teu trabalho também ❤️✊🏻✊🏻, pk=18103130803431375, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgFc_56E&_nc_gid=aedff0ffa1f74a71a2dfbb7becc84fc9&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAjsDOf2MpMtQBWQl6bq4dueRisLu1VLN-xvtClhAR3hA&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=18103130803431375, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |14342     |390          |
# |{private_reply_status=0, share_enabled=false, created_at=1726175796, type=1, is_covered=false, created_at_utc=1726175796, content_type=comment, user_id=482001976, bit_flags=0, media_id=3455734369313129565, text=#tbt & #tdah, pk=17939973362864228, did_report_as_spam=false, user={is_private=false, pk_id=482001976, profile_pic_id=3436382941194761236_482001976, fbid_v2=17841400539287531, is_verified=true, full_name=Marcito Castro, is_unpublished=false, id=482001976, pk=482001976, profile_pic_url=https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/455822620_1019247976559485_5672978017921992113_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=N_yyuRP2Ba0Q7kNvgFc_56E&_nc_gid=aedff0ffa1f74a71a2dfbb7becc84fc9&edm=ABmJApABAAAA&ccb=7-5&oh=00_AYAjsDOf2MpMtQBWQl6bq4dueRisLu1VLN-xvtClhAR3hA&oe=66EBAE67&_nc_sid=b41fef, username=marcitocastro, strong_id__=482001976}, is_ranked_comment=false, strong_id__=17939973362864228, status=Active}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |14886     |161          |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Extraindo Comentários / Get comments

# %%
codigo_ultima_postagem
# Out:
# 'C_4LTB9Oiym'

# %%
querystring = {"code_or_id_or_url":codigo_ultima_postagem,"sort_order":"popular","min_id":None}

# "min_id":"teste"
method = 'media_comments'
min_id = None

aux = 1


data_comments = []

while True:
  print('Executando')
  print(aux)
  aux = aux+1
  querystring = {"code_or_id_or_url":codigo_ultima_postagem,"sort_order":"recent","min_id":min_id}
  print(f'parameters: {querystring}')

  response = requests.get(f'{url}{method}',
                        headers=headers,
                        params=querystring)


  response_instagram = response.json()

  array_comments = response_instagram.get('data').get('comments')

  for comment in array_comments:
    pk = comment.get('pk')
    user_id = comment.get('user_id')
    text = comment.get('text')
    comment_like_count = comment.get('comment_like_count',0)
    child_comment_count = comment.get('child_comment_count',0)
    user_username = comment.get('user').get('username')
    user_full_name = comment.get('user').get('full_name')
    user_is_verified = comment.get('user').get('is_verified')
    data_comments.append((pk,user_id,text,comment_like_count,child_comment_count,user_username,user_full_name,user_is_verified))

  print(f'min_id_antes: {min_id}')
  min_id = response_instagram.get('data').get('next_min_id')
  print(f'min_id_depois: {min_id}')


  # Se não houver mais itens a serem buscados, encerra o loop
  if not min_id:
    break

schema = StructType([
  StructField("pk", StringType(), nullable=True),
  StructField("user_id", StringType(), nullable=True),
  StructField("text", StringType(), nullable=True),
  StructField("comment_like_count", StringType(), nullable=True),
  StructField("child_comment_count", StringType(), nullable=True),
  StructField("user_username", StringType(), nullable=True),
  StructField("user_full_name", StringType(), nullable=True),
  StructField("user_is_verified", StringType(), nullable=True)
])



print(data_comments)

df = spark.createDataFrame(data_comments, schema=schema)

# # Criando o DataFrame
# df = spark.createDataFrame(data, columns)

df = df.withColumn('ts_exec', F.current_timestamp())

# # Mostrando o DataFrame
df.write.mode("append").format('parquet').save('/content/Datalake/Instagram/comentarios/')

df.show(truncate=False)
# Out:
# Executando
# 1
# parameters: {'code_or_id_or_url': 'C_4LTB9Oiym', 'sort_order': 'recent', 'min_id': None}
# min_id_antes: None
# min_id_depois: {"server_cursor": "QVFETnl3ZzdqdjNwRF9aRm5TTkdmczUwNlliRFJCcUptZzNweHN6ZjR3Z1hnRjdoY0l3aGluZ0NEVVpfWG13bzdXTnQybU9HTndNeklYTEV4Mk1Fc1pNT21EMXR5blVMMlJvdmJlM0RRcmVZZHc=", "is_server_cursor_inverse": true}
# Executando
# 2
# parameters: {'code_or_id_or_url': 'C_4LTB9Oiym', 'sort_order': 'recent', 'min_id': '{"server_cursor": "QVFETnl3ZzdqdjNwRF9aRm5TTkdmczUwNlliRFJCcUptZzNweHN6ZjR3Z1hnRjdoY0l3aGluZ0NEVVpfWG13bzdXTnQybU9HTndNeklYTEV4Mk1Fc1pNT21EMXR5blVMMlJvdmJlM0RRcmVZZHc=", "is_server_cursor_inverse": true}'}
# min_id_antes: {"server_cursor": "QVFETnl3ZzdqdjNwRF9aRm5TTkdmczUwNlliRFJCcUptZzNweHN6ZjR3Z1hnRjdoY0l3aGluZ0NEVVpfWG13bzdXTnQybU9HTndNeklYTEV4Mk1Fc1pNT21EMXR5blVMMlJvdmJlM0RRcmVZZHc=", "is_server_cursor_inverse": true}
# min_id_depois: {"server_cursor": "QVFEWEhPQm5Dd3lrV2ZTZ2R5N1FKTHhZemZtZXJNakZ4M2hGVXZmWG1tRkZ4NnVvMUFuRU85MDFKakJXU1FSODZvblVjMkp3TjI1Vm1yZVRudTBMMElBU2dSVzZrbmhhWEV4WTFCTDdJRjNnRUE=", "is_server_cursor_inverse": true}
# Executando
# 3
# parameters: {'code_or_id_or_url': 'C_4LTB9Oiym', 'sort_order': 'recent', 'min_id': '{"server_cursor": "QVFEWEhPQm5Dd3lrV2ZTZ2R5N1FKTHhZemZtZXJNakZ4M2hGVXZmWG1tRkZ4NnVvMUFuRU85MDFKakJXU1FSODZvblVjMkp3TjI1Vm1yZVRudTBMMElBU2dSVzZrbmhhWEV4WTFCTDdJRjNnRUE=", "is_server_cursor_inverse": true}'}
# min_id_antes: {"server_cursor": "QVFEWEhPQm5Dd3lrV2ZTZ2R5N1FKTHhZemZtZXJNakZ4M2hGVXZmWG1tRkZ4NnVvMUFuRU85MDFKakJXU1FSODZvblVjMkp3TjI1Vm1yZVRudTBMMElBU2dSVzZrbmhhWEV4WTFCTDdJRjNnRUE=", "is_server_cursor_inverse": true}
# min_id_depois: None
# [('18005807120444830', '4393326110', 'Te puxou na música!!!Adoroooo!!!', 0, 0, 'cris_maede6', 'Cris Gomes', False), ('18009711506374117', '49315858380', '@matheus_mendonca07 olha ali tua vó', 0, 0, 'getuliosp_', 'Getulio Pinheiro', False), ('18023208887159370', '12087840764', 'Marquei presença. Muito bom 👏👏👏👏', 0, 0, 'julioborges1972', 'Julio Borges', False), ('17938039067877598', '7225238930', 'Muito bom o show 👏👏 satisfação em te rever @miguel.kromado sucesso sempre 🙏🏻', 0, 0, 'marcelemenegotte', 'Marcele Menegotte', False), ('18460476004038968', '986327355', 'Baita show', 0, 0, 'eufranzin', 'Franciele Barbosa', False), ('17860646562183203', '59920425300', 'Parabéns pelo seu trabalho Marcito, estava top demais, sucesso sempre 👏', 0, 0, 'cristianovmenezes', 'Cristiano Menezes', False), ('18111165166407947', '13115978', 'Amo as músicas ❤️ mas o show tb é bom 😂', 3, 0, 'carol_reque', 'Carol', False), ('18041220442874041', '4866120747', '🔥🔥🔥', 1, 0, 'quelen.cardoso', 'Quelen Cardoso', False), ('18001495397660832', '7155184137', '👏👏👏', 0, 0, 'vt7_apns', 'Vitinho', False), ('18041632540864877', '19684862966', 'Que lindo isso!!!! 😍', 0, 0, 'lu_lupiaf', 'Lucimar F Sique
tava incrível...adorei te conhecer,muito gente boa tu és..sucessooooo🫶         |2                 |0                  |daygomesday         |Day Gomes                    |false           |2024-09-14 18:35:31.071|
# |17845749951287626|53131577213|Eu fui cupinxa!👏                                                               |3                 |1                  |rudinei.santos.7    |Rudinei Santos               |false           |2024-09-14 18:35:31.071|
# |18001752278662214|9977800391 |👏👏                                                                            |1                 |0                  |soniamellocoitinho  |Sonia Mello Coitinho         |false           |2024-09-14 18:35:31.071|
# |18042403184059390|7130772182 |Foi demais                                                                      |2                 |0                  |daiane_santos84     |Daiane Santos                |false           |2024-09-14 18:35:31.071|
# |18039801635094854|54201709783|Que baitaaaa 🔥🔥👏🏿👏🏿                                                       |1                 |0                  |juliano_costa_silva_|Carlos Juliano Costa Da Silva|false           |2024-09-14 18:35:31.071|
# +-----------------+-----------+--------------------------------------------------------------------------------+------------------+-------------------+--------------------+-----------------------------+----------------+-----------------------+
# only showing top 20 rows

# %%
spark.read.parquet('/content/Datalake/Instagram/comentarios/').createOrReplaceTempView('comentarios')

spark.sql('select text from comentarios').show(truncate=False)
# Out:
# +-------------------------------------------------------------------------+
# |text                                                                     |
# +-------------------------------------------------------------------------+
# |Foi demais                                                               |
# |Que baitaaaa 🔥🔥👏🏿👏🏿                                                |
# |👏🙌❤️👏👏                                                               |
# |👏🏼👏🏼                                                                 |
# |Baita dupla 🔥 voltem logo ❤️                                            |
# |Estava ótimo!                                                            |
# |Minha terra natal 👏👏👏.                                                |
# |Muito bom, parabéns pelo show 👏👏👏👏                                   |
# |Queria muuuito ter ido 🥹❤️ meu coração dói                              |
# |Noite alta na minha cidade. Obrigado Guaíba!                             |
# |👏👏👏👏👏👏                                                             |
# |Ficou show a foto!                                                       |
# |👏👏👏👏                                                                 |
# |que momento!!                                                            |
# |Foodaaa🤌🏾👏🏾                                                          |
# |Tá apaixonado só pela música 😂                                          |
# |👏                                                                       |
# |show espetacular, muito foda marcito!!!!!                                |
# |Lá do Sarandi para o mundo te conheci lá pelas bandas do lojao do alemão.|
# |Foi demais                                                               |
# +-------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ## Análises / Analytics

# %%
spark.read.parquet('/content/Datalake/Instagram/Perfil_v2/')\
  .select('nome_perfil','seguidores_num','ts_exec')\
  .where("id!='3444000070552872069_482001976'")\
  .orderBy('ts_exec',ascending=True)\
  .show(truncate=False)
# Out:
# +--------------+--------------+--------------------------+
# |nome_perfil   |seguidores_num|ts_exec                   |
# +--------------+--------------+--------------------------+
# |Marcito Castro|818673        |2024-09-14 18:04:46.636433|
# |Marcito Castro|null          |2024-09-14 18:34:35.627   |
# +--------------+--------------+--------------------------+

# %%
df_pandas = spark.read.parquet('/content/Datalake/Instagram/comentarios/').select('text').toPandas()

# %% [markdown]
# ## Classificação de comentários / Comment Rating

# %% [markdown]
# #### Desenvolvimento / Development

# %%
genai.configure(api_key="AIzaSyDV_aPlCVJ0c0jNmxuADvOJPmk5ZqP7LfM")
model = genai.GenerativeModel('gemini-1.5-flash')

def classifica_comentario(p_text):
  """
  Classifica o sentimento de um texto usando a API do Gemini.
  Args:
    text:
  """
  pergunta = f'Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: {p_text}'

  print(pergunta)
  response = model.generate_content(pergunta)
  return response.text

# %% [markdown]
# ##### Cruza os comentários com as classificações e monta um array com os comentários que precisam ser classificados
# Cross-references the comments with the ratings and creates an array with the comments that need to be rated

# %%
df_comentarios = spark.read.parquet('/content/Datalake/Instagram/comentarios')
df_classificacao = spark.read.parquet('/content/Datalake/Instagram/comentarios_classificacao/')


df_comentarios_para_classificar = df_comentarios.join(df_classificacao, 'pk', 'left')

df_comentarios_para_classificar.createOrReplaceTempView('comentarios_para_classificar')
df = spark.sql('select pk,text,classificacao from comentarios_para_classificar where classificacao is null')

lista_linhas = df.rdd.map(lambda row: row.asDict()).collect()

lista_linhas
# Out:
# [{'pk': '18034068122511316', 'text': '👏', 'classificacao': None},
#  {'pk': '18035902823179707',
#   'text': 'show espetacular, muito foda marcito!!!!!',
#   'classificacao': None},
#  {'pk': '17935776377793414',
#   'text': 'Lá do Sarandi para o mundo te conheci lá pelas bandas do lojao do alemão.',
#   'classificacao': None},
#  {'pk': '18034068122511316', 'text': '👏', 'classificacao': None},
#  {'pk': '18035902823179707',
#   'text': 'show espetacular, muito foda marcito!!!!!',
#   'classificacao': None},
#  {'pk': '17935776377793414',
#   'text': 'Lá do Sarandi para o mundo te conheci lá pelas bandas do lojao do alemão.',
#   'classificacao': None},
#  {'pk': '18034068122511316', 'text': '👏', 'classificacao': None},
#  {'pk': '18035902823179707',
#   'text': 'show espetacular, muito foda marcito!!!!!',
#   'classificacao': None},
#  {'pk': '17935776377793414',
#   'text': 'Lá do Sarandi para o mundo te conheci lá pelas bandas do lojao do alemão.',
#   'classificacao': None},
#  {'pk': '18000891767499844',
#   'text': 'Só te falta um fotógrafo ein 🚀📸',
#   'classificacao': None},
#  {'pk': '18005807120444830',
#   'text': 'Te puxou na música!!!Adoroooo!!!',
#   'classificacao': None},
#  {'pk': '18009711506374117',
#   'text': '@matheus_mendonca07 olha ali tua vó',
#   'classificacao': None},
#  {'pk': '18023208887159370',
#   'text': 'Marquei presença. Muito bom 👏👏👏👏',
#   'classificacao': None},
#  {'pk': '17938039067877598',
#   'text': 'Muito bom o show 👏👏 satisfação em te rever @miguel.kromado sucesso sempre 🙏🏻',
#   'classificacao': None},
#  {'pk': '18460476004038968', 'text': 'Baita show', 'classificacao': None},
#  {'pk': '17860646562183203',
#   'text': 'Parabéns pelo seu trabalho Marcito, estava top demais, sucesso sempre 👏',
#   'classificacao': None},
#  {'pk': '18111165166407947',
#   'text': 'Amo as músicas ❤️ mas o show tb é bom 😂',
#   'classificacao': None},
#  {'pk': '18041220442874041', 'text': '🔥🔥🔥', 'classificacao': None},
#  {'pk': '18001495397660832', 'text': '👏👏👏', 'classificacao': None},
#  {'pk': '18041632540864877',
#   'text': 'Que lindo isso!!!! 😍',
#   'classificacao': None},
#  {'pk': '18019166138613294', 'text': 'Bah né', 'classificacao': None},
#  {'pk': '17895071754065181', 'text': '👏👏👏', 'classificacao': None},
#  {'pk': '17967858437788764', 'text': '👏👏👏👏👏', 'classificacao': None},
#  {'pk': '17847872814271640',
#   'text': 'Show sensacional👏🏻👏🏻',
#   'classificacao': None},
#  {'pk': '18015931085303864',
#   'text': 'Muito  além das expectativas!!! Bom demais!!! 😍👏👏',
#   'classificacao': None},
#  {'pk': '18093694384464959',
#   'text': 'Tava incrível...adorei te conhecer,muito gente boa tu és..sucessooooo\U0001faf6',
#   'classificacao': None},
#  {'pk': '17845749951287626',
#   'text': 'Eu fui cupinxa!👏',
#   'classificacao': None},
#  {'pk': '18001752278662214', 'text': '👏👏', 'classificacao': None},
#  {'pk': '18000891767499844',
#   'text': 'Só te falta um fotógrafo ein 🚀📸',
#   'classificacao': None},
#  {'pk': '18005807120444830',
#   'text': 'Te puxou na música!!!Adoroooo!!!',
#   'classificacao': None},
#  {'pk': '18009711506374117',
#   'text': '@matheus_mendonca07 olha ali tua vó',
#   'classificacao': None},
#  {'pk': '18023208887159370',
#   'text': 'Marquei presença. Muito bom 👏👏👏👏',
#   'classificacao': None},
#  {'pk': '17938039067877598',
#   'text': 'Muito bom o show 👏👏 satisfação em te rever @miguel.kromado sucesso sempre 🙏🏻',
#   'classificacao': None},
#  {'pk': '18460476004038968', 'text': 'Baita show', 'classificacao': None},
#  {'pk': '17860646562183203',
#   'text': 'Parabéns pelo seu trabalho Marcito, estava top demais, sucesso sempre 👏',
#   'classificacao': None},
#  {'pk': '18111165166407947',
#   'text': 'Amo as músicas ❤️ mas o show tb é bom 😂',
#   'classificacao': None},
#  {'pk': '18041220442874041', 'text': '🔥🔥🔥', 'classificacao': None},
#  {'pk': '18001495397660832', 'text': '👏👏👏', 'classificacao': None},
#  {'pk': '18041632540864877',
#   'text': 'Que lindo isso!!!! 😍',
#   'classificacao': None},
#  {'pk': '18019166138613294', 'text': 'Bah né', 'classificacao': None},
#  {'pk': '17895071754065181', 'text': '👏👏👏', 'classificacao': None},
#  {'pk': '17967858437788764', 'text': '👏👏👏👏👏', 'classificacao': None},
#  {'pk': '17847872814271640',
#   'text': 'Show sensacional👏🏻👏🏻',
#   'classificacao': None},
#  {'pk': '18015931085303864',
#   'text': 'Muito  além das expectativas!!! Bom demais!!! 😍👏👏',
#   'classificacao': None},
#  {'pk': '18093694384464959',
#   'text': 'Tava incrível...adorei te conhecer,muito gente boa tu és..sucessooooo\U0001faf6',
#   'classificacao': None},
#  {'pk': '17845749951287626',
#   'text': 'Eu fui cupinxa!👏',
#   'classificacao': None},
#  {'pk': '18001752278662214', 'text': '👏👏', 'classificacao': None},
#  {'pk': '18005807120444830',
#   'text': 'Te puxou na música!!!Adoroooo!!!',
#   'classificacao': None},
#  {'pk': '18009711506374117',
#   'text': '@matheus_mendonca07 olha ali tua vó',
#   'classificacao': None},
#  {'pk': '18023208887159370',
#   'text': 'Marquei presença. Muito bom 👏👏👏👏',
#   'classificacao': None},
#  {'pk': '17938039067877598',
#   'text': 'Muito bom o show 👏👏 satisfação em te rever @miguel.kromado sucesso sempre 🙏🏻',
#   'classificacao': None},
#  {'pk': '18460476004038968', 'text': 'Baita show', 'classificacao': None},
#  {'pk': '17860646562183203',
#   'text': 'Parabéns pelo seu trabalho Marcito, estava top demais, sucesso sempre 👏',
#   'classificacao': None},
#  {'pk': '18111165166407947',
#   'text': 'Amo as músicas ❤️ mas o show tb é bom 😂',
#   'classificacao': None},
#  {'pk': '18041220442874041', 'text': '🔥🔥🔥', 'classificacao': None},
#  {'pk': '18001495397660832', 'text': '👏👏👏', 'classificacao': None},
#  {'pk': '18041632540864877',
#   'text': 'Que lindo isso!!!! 😍',
#   'classificacao': None},
#  {'pk': '18019166138613294', 'text': 'Bah né', 'classificacao': None},
#  {'pk': '17895071754065181', 'text': '👏👏👏', 'classificacao': None},
#  {'pk': '17967858437788764', 'text': '👏👏👏👏👏', 'classificacao': None},
#  {'pk': '17847872814271640',
#   'text': 'Show sensacional👏🏻👏🏻',
#   'classificacao': None},
#  {'pk': '18015931085303864',
#   'text': 'Muito  além das expectativas!!! Bom demais!!! 😍👏👏',
#   'classificacao': None},
#  {'pk': '18093694384464959',
#   'text': 'Tava incrível...adorei te conhecer,muito gente boa tu és..sucessooooo\U0001faf6',
#   'classificacao': None},
#  {'pk': '17845749951287626',
#   'text': 'Eu fui cupinxa!👏',
#   'classificacao': None},
#  {'pk': '18001752278662214', 'text': '👏👏', 'classificacao': None}]

# %%
array_comments_analise = []

for comentario in lista_linhas:
  pk = comentario.get('pk')
  text = comentario.get('text')

  retorno_ai = classifica_comentario(text)

  array_comments_analise.append((pk,text,retorno_ai))
# Out:
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Foi demais
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Que baitaaaa 🔥🔥👏🏿👏🏿
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: 👏🙌❤️👏👏
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: 👏🏼👏🏼
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Baita dupla 🔥 voltem logo ❤️
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Estava ótimo!
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Minha terra natal 👏👏👏.
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Muito bom, parabéns pelo show 👏👏👏👏
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Queria muuuito ter ido 🥹❤️ meu coração dói
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Noite alta na minha cidade. Obrigado Guaíba!
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: 👏👏👏👏👏👏
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Ficou show a foto!
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: 👏👏👏👏
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: que momento!!
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Foodaaa🤌🏾👏🏾
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: Tá apaixonado só pela música 😂
# Classifique o comentário a seguir em (positivo, negativo, neutro, humor), retorno apenas a classificação: 👏
# WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 535.25ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-34-d6e06f24393a> in <cell line: 3>()
#       5   text = comentario.get('text')
#       6
# ----> 7   retorno_ai = classifica_comentario(text)
#       8
#       9   array_comments_analise.append((pk,text,retorno_ai))
#
# <ipython-input-26-fec765a574d3> in classifica_comentario(p_text)
#      15
#      16   print(pergunta)
# ---> 17   response = model.generate_content(pergunta)
#      18   return response.text
#      19
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     828
#     829         # Send the request.
# --> 830         response = rpc(
#     831             request,
#     832             retry=retry,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     291                 self._initial, self._maximum, multiplier=self._multiplier
#     292             )
# --> 293             return retry_target(
#     294                 target,
#     295                 self._predicate,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151         except Exception as exc:
#     152             # defer to shared logic for handling errors
# --> 153             _retry_error_helper(
#     154                 exc,
#     155                 deadline,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     210             original_timeout,
#     211         )
# --> 212         raise final_exc from source_exc
#     213     if on_error_fn is not None:
#     214         on_error_fn(exc)
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142     for sleep in sleep_generator:
#     143         try:
# --> 144             result = target()
#     145             if inspect.isawaitable(result):
#     146                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     118                 kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#     122         return func_with_timeout
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      74     def error_remapped_callable(*args, **kwargs):
#      75         try:
# ---> 76             return callable_(*args, **kwargs)
#      77         except grpc.RpcError as exc:
#      78             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#     845             # subclass.
#     846             if response.status_code >= 400:
# --> 847                 raise core_exceptions.from_http_response(response)
#     848
#     849             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).

# %%
schema = StructType([
  StructField("pk", StringType(), nullable=True),
  StructField("text_original", StringType(), nullable=True),
  StructField("classificacao", StringType(), nullable=True)
])

print(data_comments)

df = spark.createDataFrame(array_comments_analise, schema=schema)
df = df.withColumn('ts_exec', F.current_timestamp())

df.write.mode("append").format('parquet').save('/content/Datalake/Instagram/comentarios_classificacao/')
# Out:
muito bom, parabéns pelo show 👏👏👏👏', 2, 0, 'alinenuneslima85', 'Aline Nunes de Lima', False), ('17858945073247452', '67151269030', 'Queria muuuito ter ido \U0001f979❤️ meu coração dói', 1, 0, 'andressanunesdasilva28', 'Andressa Silva', False), ('18090171229480205', '755728746', 'Noite alta na minha cidade. Obrigado Guaíba!', 14, 3, 'miguel.kromado', 'Miguel Kromado', False), ('18350315176187840', '54402976696', '👏👏👏👏👏👏', 1, 0, 'niteroicanoas', 'Niterói Canoas', False), ('17916264428985759', '4853241112', 'Ficou show a foto!', 1, 0, 'lisianeprzybilski', 'Lisiane Przybilski', False), ('18090708421432424', '14969355757', '👏👏👏👏', 2, 0, 'guridafarmacia', 'Guri da Farmácia - Diego Capela', False), ('18143246011340539', '14731780180', 'que momento!!', 2, 0, 'gustavodeleski', 'Gustavo Deleski', False), ('17938443758868910', '1343714940', 'Foodaaa🤌🏾👏🏾', 1, 0, 'lucasslily', 'Lilian Lucas', False), ('18034802423162429', '9399206570', 'Tá apaixonado só pela música 😂', 2, 0, 'onixrs_malvadao', '😈 MALVADÃO 😈 Diferente dos Iguais', False), ('18034068122511316', '55232012888', '👏', 1, 0, 'portoalegre.milgrau', '𝗣𝗢𝗥𝗧𝗢 𝗔𝗟𝗘𝗚𝗥𝗘  ...

# %%
df_comentarios = spark.read.parquet('/content/Datalake/Instagram/comentarios/')
df_classificacao = spark.read.parquet('/content/Datalake/Instagram/comentarios_classificacao/')

df_comentarios_para_classificar = df_comentarios.join(df_classificacao, 'pk', 'left')

df_comentarios_para_classificar.createOrReplaceTempView('comentarios_para_classificar')

spark.sql('select *  from comentarios_para_classificar where text like("%parabéns%")').show(truncate=False)
# Out:
# +-----------------+----------+--------------------------------------+------------------+-------------------+----------------+-------------------+----------------+--------------------------+--------------------------------------+-------------+-----------------------+
# |pk               |user_id   |text                                  |comment_like_count|child_comment_count|user_username   |user_full_name     |user_is_verified|ts_exec                   |text_original                         |classificacao|ts_exec                |
# +-----------------+----------+--------------------------------------+------------------+-------------------+----------------+-------------------+----------------+--------------------------+--------------------------------------+-------------+-----------------------+
# |18095314462414642|5634155107|Muito bom, parabéns pelo show 👏👏👏👏|2                 |0                  |alinenuneslima85|Aline Nunes de Lima|false           |2024-09-14 18:27:28.668379|Muito bom, parabéns pelo show 👏👏👏👏|Positivo
#    |2024-09-14 19:30:56.127|
# |18095314462414642|5634155107|Muito bom, parabéns pelo show 👏👏👏👏|2                 |0                  |alinenuneslima85|Aline Nunes de Lima|false           |2024-09-14 18:27:40.583781|Muito bom, parabéns pelo show 👏👏👏👏|Positivo
#    |2024-09-14 19:30:56.127|
# |18095314462414642|5634155107|Muito bom, parabéns pelo show 👏👏👏👏|2                 |0                  |alinenuneslima85|Aline Nunes de Lima|false           |2024-09-14 18:35:30.4     |Muito bom, parabéns pelo show 👏👏👏👏|Positivo
#    |2024-09-14 19:30:56.127|
# +-----------------+----------+--------------------------------------+------------------+-------------------+----------------+-------------------+----------------+--------------------------+--------------------------------------+-------------+-----------------------+
